# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import  warnings
warnings.filterwarnings('ignore')
import sqlite3
import csv

# %% [markdown]
# # 3.1) Insert records from 42_District_wise_crimes_committed_against_women_2001_2012.csv into a table

# %%
df=pd.read_csv(r"C:\Nimish\Flip Robo\42_District_wise_crimes_committed_against_women_2001_2012.csv")
df
# Out:
#             STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1     ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2     ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3     ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4     ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
# ...              ...            ...   ...   ...                       ...
# 9012     LAKSHADWEEP    LAKSHADWEEP  2012     0                         0
# 9013     LAKSHADWEEP          TOTAL  2012     0                         0
# 9014      PUDUCHERRY       KARAIKAL  2012     6                         2
# 9015      PUDUCHERRY     PUDUCHERRY  2012     7                        14
# 9016      PUDUCHERRY          TOTAL  2012    13                        16
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0               16                                                149
# 1                7                                                118
# 2               14                                                112
# 3               17                                                126
# 4               12                                                109
# ...            ...                                                ...
# 9012             0                                                  1
# 9013             0                                                  1
# 9014             0                                                  2
# 9015             0                                                  7
# 9016             0                                                  9
#
#       Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# 0                             34                                  175
# 1                             24                                  154
# 2                             83                                  186
# 3                             38                                   57
# 4                             58                                  247
# ...                          ...                                  ...
# 9012                           0                                    1
# 9013                           0                                    1
# 9014                           0                                    1
# 9015                           2                                    5
# 9016                           2                                    6
#
#       Importation of Girls
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 9012                     0
# 9013                     0
# 9014                     0
# 9015                     0
# 9016                     0
#
# [9017 rows x 10 columns]

# %%
db=sqlite3.connect('crime_database.db')
cursor=db.cursor()
cursor.execute("CREATE TABLE Crimes_against_women(State_UT text, District text, Year int, Rape int, Kidnapping_abduction int, Dowry_Deaths int,Assault_on_women_with_intent_to_outrage_her_modesty int,Insult_to_modesty_of_Women int,Cruelty_by_Husband_or_His_Relatives int,Importation_of_Girls int)")

# %%
with open(r"C:\Nimish\Flip Robo\42_District_wise_crimes_committed_against_women_2001_2012.csv") as file:
    no_records=0
    for row in file:
        cursor.execute('INSERT INTO Crimes_against_women VALUES(?,?,?,?,?,?,?,?,?,?)',row.split(','))
        db.commit()
        no_records +=1

print(no_records,"record(s) printed")
# Out:
# 9018 record(s) printed

# %% [markdown]
# We have inserted all the details into our Crimes_against_women table

# %% [markdown]
# # 3.2) Write SQL query to find the highest number of rapes & Kidnappings that happened in which state, District, and year.

# %%
result=cursor.execute("SELECT State_UT, District, Year, Rape, Kidnapping_abduction FROM Crimes_against_women WHERE District NOT LIKE '%Total%'ORDER BY (Rape + Kidnapping_abduction) DESC LIMIT 1;")
result.fetchall()
# Out:
# [('"WEST BENGAL"', '"MURSHIDABAD"', 2010, 526, 441)]

# %% [markdown]
# As we can see West Bengal's Murshidabad is the district with highest number of rapes and kidnappings combined that happened in the year 2010

# %% [markdown]
# # 3.3)	Write SQL query to find All the lowest number of rapes & Kidnappings that happened in which state, District, and year

# %%
result=cursor.execute("SELECT State_UT, District, Year, Rape, Kidnapping_abduction FROM Crimes_against_women WHERE ( Rape, Kidnapping_abduction) IN ( SELECT MIN(Rape) AS Lowest_Rape,MIN(Kidnapping_abduction) AS Lowest_Kidnapping FROM Crimes_against_women WHERE District NOT LIKE '%Total%')")
result.fetchall()
# Out:
# [('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2001, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2001, 0, 0),
#  ('"BIHAR"', '"ARWAL"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"GRP RAIPUR"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2001, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2001, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2001, 0, 0),
#  ('"MIZORAM"', '"MAMIT"', 2001, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2001, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2001, 0, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2001, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2001, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2001, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2001, 0, 0),
#  ('"WEST BENGAL"', '"ASANSOL"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"SILIGURI G.R.P."', 2001, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2001, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2001, 0, 0),
#  ('"DELHI"', '"S.T.F."', 2001, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2001, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2002, 0, 0),
#  ('"ASSAM"', '"G.R.P."', 2002, 0, 0),
#  ('"BIHAR"', '"ARWAL"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2002, 0, 0),
#  ('"KARNATAKA"', '"DHARWAD RURAL"', 2002, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2002, 0, 0),
#  ('"KERALA"', '"CBCID"', 2002, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2002, 0, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"NAGPUR RLY."', 2002, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2002, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2002, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2002, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2002, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2002, 0, 0),
#  ('"ODISHA"', '"SRP(ROURKELA)"', 2002, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2002, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2002, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2002, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2002, 0, 0),
#  ('"WEST BENGAL"', '"SEALDAH G.R.P."', 2002, 0, 0),
#  ('"DELHI"', '"G.R.P.(RLY)"', 2002, 0, 0),
#  ('"DELHI"', '"S.T.F."', 2002, 0, 0),
#  ('"DELHI"', '"SPL CELL"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2003, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2003, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2003, 0, 0),
#  ('"GUJARAT"', '"AHWA-DANG"', 2003, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2003, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2003, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2003, 0, 0),
#  ('"JHARKHAND"', '"KODERMA"', 2003, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2003, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2003, 0, 0),
#  ('"MADHYA PRADESH"', '"INDORE RLY."', 2003, 0, 0),
#  ('"MANIPUR"', '"CHURACHANDPUR"', 2003, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2003, 0, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2003, 0, 0),
#  ('"NAGALAND"', '"ZUNHEBOTO"', 2003, 0, 0),
#  ('"RAJASTHAN"', '"G.R.P."', 2003, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2003, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2003, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2003, 0, 0),
#  ('"WEST BENGAL"', '"SEALDAH G.R.P."', 2003, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2003, 0, 0),
#  ('"DELHI"', '"S.T.F."', 2003, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2004, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2004, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2004, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI LOWER"', 2004, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2004, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2004, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2004, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2004, 0, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2004, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2004, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2004, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2004, 0, 0),
#  ('"KERALA"', '"CBCID"', 2004, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2004, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2004, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2004, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2004, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS EAST"', 2004, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2004, 0, 0),
#  ('"NAGALAND"', '"MON"', 2004, 0, 0),
#  ('"NAGALAND"', '"WOKHA"', 2004, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2004, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2004, 0, 0),
#  ('"SIKKIM"', '"WEST"', 2004, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2004, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2004, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2004, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2004, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2004, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2004, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2005, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2005, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TIRAP"', 2005, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2005, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2005, 0, 0),
#  ('"BIHAR"', '"PATNA RLY."', 2005, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2005, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2005, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2005, 0, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR RLY."', 2005, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2005, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2005, 0, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2005, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2005, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2005, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2005, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2005, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2005, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2005, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2005, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2005, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2005, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2005, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2005, 0, 0),
#  ('"DELHI"', '"SPL CELL"', 2005, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2005, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2005, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2006, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2006, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2006, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2006, 0, 0),
#  ('"BIHAR"', '"JAMALPUR RLY."', 2006, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2006, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2006, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2006, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2006, 0, 0),
#  ('"JHARKHAND"', '"DHANBAD RLY."', 2006, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2006, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2006, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2006, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2006, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2006, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2006, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2006, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2006, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2006, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2006, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2006, 0, 0),
#  ('"DELHI"', '"STF"', 2006, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2006, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2006, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2007, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2007, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2007, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2007, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2007, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2007, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2007, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2007, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2007, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2007, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2007, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2007, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2007, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2007, 0, 0),
#  ('"NAGALAND"', '"MON"', 2007, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2007, 0, 0),
#  ('"NAGALAND"', '"PHEK"', 2007, 0, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2007, 0, 0),
#  ('"NAGALAND"', '"ZUNHEBOTO"', 2007, 0, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2007, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2007, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2007, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2007, 0, 0),
#  ('"DELHI"', '"STF"', 2007, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2008, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2008, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2008, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2008, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2008, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2008, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2008, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2008, 0, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR RLY."', 2008, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2008, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2008, 0, 0),
#  ('"MANIPUR"', '"CID"', 2008, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2008, 0, 0),
#  ('"MIZORAM"', '"SAIHA"', 2008, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2008, 0, 0),
#  ('"NAGALAND"', '"LONGLENG"', 2008, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2008, 0, 0),
#  ('"UTTARAKHAND"', '"PITHORAGARH"', 2008, 0, 0),
#  ('"UTTARAKHAND"', '"RUDRA PRAYAG"', 2008, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2008, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2008, 0, 0),
#  ('"DAMAN & DIU"', '"DAMAN"', 2008, 0, 0),
#  ('"DELHI"', '"CAW"', 2008, 0, 0),
#  ('"DELHI"', '"CRIME BRANCH"', 2008, 0, 0),
#  ('"DELHI"', '"EOW"', 2008, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2008, 0, 0),
#  ('"DELHI"', '"STF"', 2008, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2009, 0, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2009, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2009, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"ANJAW"', 2009, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2009, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2009, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2009, 0, 0),
#  ('"ASSAM"', '"G.R.P."', 2009, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CID"', 2009, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2009, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2009, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2009, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2009, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KMR"', 2009, 0, 0),
#  ('"JHARKHAND"', '"DHANBAD RLY."', 2009, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2009, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2009, 0, 0),
#  ('"MANIPUR"', '"CID"', 2009, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2009, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2009, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2009, 0, 0),
#  ('"NAGALAND"', '"LONGLENG"', 2009, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2009, 0, 0),
#  ('"NAGALAND"', '"MON"', 2009, 0, 0),
#  ('"NAGALAND"', '"PHEK"', 2009, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2009, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2009, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2009, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2009, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2009, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2009, 0, 0),
#  ('"DELHI"', '"CAW"', 2009, 0, 0),
#  ('"DELHI"', '"EOW"', 2009, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2009, 0, 0),
#  ('"DELHI"', '"STF"', 2009, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2010, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2010, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CID"', 2010, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2010, 0, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2010, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2010, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME KASHMIR"', 2010, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2010, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2010, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2010, 0, 0),
#  ('"MANIPUR"', '"CID"', 2010, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2010, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2010, 0, 0),
#  ('"NAGALAND"', '"LONGLENG"', 2010, 0, 0),
#  ('"NAGALAND"', '"MON"', 2010, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2010, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2010, 0, 0),
#  ('"RAJASTHAN"', '"G.R.P. AJMER"', 2010, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2010, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2010, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2010, 0, 0),
#  ('"TRIPURA"', '"G.R.P."', 2010, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2010, 0, 0),
#  ('"DELHI"', '"CAW"', 2010, 0, 0),
#  ('"DELHI"', '"CRIME BRANCH"', 2010, 0, 0),
#  ('"DELHI"', '"EOW"', 2010, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2010, 0, 0),
#  ('"DELHI"', '"STF"', 2010, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2010, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2010, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2011, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"ANJAW"', 2011, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2011, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2011, 0, 0),
#  ('"BIHAR"', '"JAMALPUR RLY."', 2011, 0, 0),
#  ('"GUJARAT"', '"CID CRIME"', 2011, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CID"', 2011, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2011, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2011, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2011, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS JAMMU"', 2011, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KASHMIR"', 2011, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2011, 0, 0),
#  ('"MADHYA PRADESH"', '"BHOPAL RLY."', 2011, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2011, 0, 0),
#  ('"MANIPUR"', '"CID"', 2011, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2011, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2011, 0, 0),
#  ('"NAGALAND"', '"KOHIMA"', 2011, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2011, 0, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2011, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2011, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2011, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2011, 0, 0),
#  ('"TRIPURA"', '"GRP"', 2011, 0, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2011, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2011, 0, 0),
#  ('"DELHI"', '"EOW"', 2011, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2011, 0, 0),
#  ('"DELHI"', '"STF"', 2011, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2011, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2011, 0, 0),
#  ('"PUDUCHERRY"', '"KARAIKAL"', 2011, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2012, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2012, 0, 0),
#  ('"ASSAM"', '"BIEO"', 2012, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CID"', 2012, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2012, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2012, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2012, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS JAMMU"', 2012, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KATRA"', 2012, 0, 0),
#  ('"MANIPUR"', '"CID"', 2012, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2012, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2012, 0, 0),
#  ('"NAGALAND"', '"LONGLENG"', 2012, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2012, 0, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2012, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2012, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2012, 0, 0),
#  ('"TRIPURA"', '"GRP"', 2012, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2012, 0, 0),
#  ('"DELHI"', '"CAW"', 2012, 0, 0),
#  ('"DELHI"', '"EOW"', 2012, 0, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2012, 0, 0),
#  ('"DELHI"', '"STF"', 2012, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2012, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2012, 0, 0)]

# %% [markdown]
# We have found all the states with their corresponding districts with the lowest value that is 0 cases combined for rape and kidnapping.

# %% [markdown]
# # 3.4 ) Insert records from 02_District_wise_crimes_committed_against_ST_2001_2012.csv into a new table

# %%
df1=pd.read_csv(r"C:\Nimish\Flip Robo\02_District_wise_crimes_committed_against_ST_2001_2012.csv")
df1
# Out:
#             STATE/UT       DISTRICT  Year  Murder  Rape  Kidnapping Abduction  \
# 0     ANDHRA PRADESH       ADILABAD  2001       0     1                     2
# 1     ANDHRA PRADESH      ANANTAPUR  2001       0     0                     0
# 2     ANDHRA PRADESH       CHITTOOR  2001       0     0                     0
# 3     ANDHRA PRADESH       CUDDAPAH  2001       0     0                     0
# 4     ANDHRA PRADESH  EAST GODAVARI  2001       0     0                     0
# ...              ...            ...   ...     ...   ...                   ...
# 9013     LAKSHADWEEP    LAKSHADWEEP  2012       0     0                     0
# 9014     LAKSHADWEEP          TOTAL  2012       0     0                     0
# 9015      PUDUCHERRY       KARAIKAL  2012       0     0                     0
# 9016      PUDUCHERRY     PUDUCHERRY  2012       0     0                     0
# 9017      PUDUCHERRY          TOTAL  2012       0     0                     0
#
#       Dacoity  Robbery  Arson  Hurt  Protection of Civil Rights (PCR) Act  \
# 0           0        0      0     2                                     0
# 1           0        0      0     7                                     0
# 2           0        0      0     2                                     0
# 3           0        0      0     2                                     0
# 4           0        0      0     0                                     0
# ...       ...      ...    ...   ...                                   ...
# 9013        0        0      0     0                                     0
# 9014        0        0      0     0                                     0
# 9015        0        0      0     0                                     0
# 9016        0        0      0     0                                     0
# 9017        0        0      0     0                                     0
#
#       Prevention of atrocities (POA) Act  Other Crimes Against STs
# 0                                      0                        13
# 1                                      1                         6
# 2                                      0                         0
# 3                                      2                         0
# 4                                      0                        14
# ...                                  ...                       ...
# 9013                                   0                         0
# 9014                                   0                         0
# 9015                                   0                         0
# 9016                                   0                         0
# 9017                                   0                         0
#
# [9018 rows x 13 columns]

# %%
cursor.execute("CREATE TABLE crime_against_st (state_UT TEXT,District TEXT,Year INT,Murder INT,Rape INT,Kidanpping_abduction INT, Dacoity int, Roberry int, Arson int, Hurt int, Protection of Civil Rights Act int, Prevention of atrocities Act int, Other Crimes Against STs int)")

# %%
with open(r"C:\Nimish\Flip Robo\02_District_wise_crimes_committed_against_ST_2001_2012.csv") as file:
    no_records=0
    for row in file:
        cursor.execute('INSERT INTO crime_against_st VALUES(?,?,?,?,?,?,?,?,?,?,?,?,?)',row.split(','))
        db.commit()
        no_records +=1

print(no_records,"record(s) printed")
# Out:
# 9019 record(s) printed

# %% [markdown]
# # 3.5)	Write SQL query to find the highest number of dacoity/robbery in which district.

# %%
result=cursor.execute("SELECT state_UT, District,Year, MAX(Dacoity) AS Highest_Dacoity FROM crime_against_st GROUP BY state_UT, District, Year ORDER BY Highest_Dacoity DESC LIMIT 2")
result.fetchall()
# Out:
# [('"STATE/UT"', '"DISTRICT"', '"Year"', '"Dacoity"'),
#  ('"GUJARAT"', '"DAHOD"', 2004, 29)]

# %% [markdown]
# As we can see highest cases of dacoity occured in Dahod district of Gujarat against ST's in the year 2004.

# %% [markdown]
# # 3.6)	Write SQL query to find in which districts(All) the lowest number of murders happened

# %%
result=cursor.execute("SELECT State_UT, District, Year, Rape, Murder FROM crime_against_st WHERE (Murder) IN ( SELECT MIN(Murder) AS Lowest_murder FROM crime_against_st WHERE District NOT LIKE '%Total%')")
result.fetchall()
# Out:
# [('"ANDHRA PRADESH"', '"ADILABAD"', 2001, 1, 0),
#  ('"ANDHRA PRADESH"', '"ANANTAPUR"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"CHITTOOR"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"CUDDAPAH"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"EAST GODAVARI"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTUR"', 2001, 2, 0),
#  ('"ANDHRA PRADESH"', '"HYDERABAD CITY"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"KARIMNAGAR"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"KRISHNA"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"KURNOOL"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"MEDAK"', 2001, 1, 0),
#  ('"ANDHRA PRADESH"', '"NIZAMABAD"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"PRAKASHAM"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"RANGA REDDY"', 2001, 2, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"SRIKAKULAM"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHA RURAL"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHAPATNAM"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIZIANAGARAM"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"WARANGAL"', 2001, 5, 0),
#  ('"ANDHRA PRADESH"', '"WEST GODAVARI"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"CHANGLANG"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"DIBANG VALLEY"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG EAST"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG WEST"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG UPPER"', 2001, 1, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG WEST"', 2001, 1, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI LOWER"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI UPPER"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2001, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TIRAP"', 2001, 0, 0),
#  ('"ASSAM"', '"BARPETA"', 2001, 0, 0),
#  ('"ASSAM"', '"BONGAIGAON"', 2001, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2001, 0, 0),
#  ('"ASSAM"', '"CACHAR"', 2001, 0, 0),
#  ('"ASSAM"', '"DARRANG"', 2001, 0, 0),
#  ('"ASSAM"', '"DHEMAJI"', 2001, 0, 0),
#  ('"ASSAM"', '"DHUBRI"', 2001, 0, 0),
#  ('"ASSAM"', '"DIBRUGARH"', 2001, 0, 0),
#  ('"ASSAM"', '"G.R.P."', 2001, 0, 0),
#  ('"ASSAM"', '"GOALPARA"', 2001, 0, 0),
#  ('"ASSAM"', '"GOLAGHAT"', 2001, 0, 0),
#  ('"ASSAM"', '"GUWAHATI CITY"', 2001, 0, 0),
#  ('"ASSAM"', '"HAILAKANDI"', 2001, 0, 0),
#  ('"ASSAM"', '"JORHAT"', 2001, 0, 0),
#  ('"ASSAM"', '"KAMRUP"', 2001, 0, 0),
#  ('"ASSAM"', '"KARBI ANGLONG"', 2001, 0, 0),
#  ('"ASSAM"', '"KARIMGANJ"', 2001, 0, 0),
#  ('"ASSAM"', '"KOKRAJHAR"', 2001, 0, 0),
#  ('"ASSAM"', '"LAKHIMPUR"', 2001, 0, 0),
#  ('"ASSAM"', '"MORIGAON"', 2001, 0, 0),
#  ('"ASSAM"', '"N.C. HILLS"', 2001, 0, 0),
#  ('"ASSAM"', '"NAGAON"', 2001, 0, 0),
#  ('"ASSAM"', '"NALBARI"', 2001, 0, 0),
#  ('"ASSAM"', '"R.P.O."', 2001, 0, 0),
#  ('"ASSAM"', '"SIBSAGAR"', 2001, 0, 0),
#  ('"ASSAM"', '"SONITPUR"', 2001, 0, 0),
#  ('"ASSAM"', '"TINSUKIA"', 2001, 0, 0),
#  ('"ASSAM"', '"TOTAL"', 2001, 0, 0),
#  ('"BIHAR"', '"ARWAL"', 2001, 0, 0),
#  ('"BIHAR"', '"AURANGABAD"', 2001, 0, 0),
#  ('"BIHAR"', '"BAGAHA"', 2001, 0, 0),
#  ('"BIHAR"', '"BANKA"', 2001, 0, 0),
#  ('"BIHAR"', '"BEGUSARAI"', 2001, 0, 0),
#  ('"BIHAR"', '"BETTIAH"', 2001, 0, 0),
#  ('"BIHAR"', '"BHABHUA"', 2001, 0, 0),
#  ('"BIHAR"', '"BHAGALPUR"', 2001, 0, 0),
#  ('"BIHAR"', '"BHOJPUR"', 2001, 0, 0),
#  ('"BIHAR"', '"BUXAR"', 2001, 0, 0),
#  ('"BIHAR"', '"DARBHANGA"', 2001, 0, 0),
#  ('"BIHAR"', '"GAYA"', 2001, 0, 0),
#  ('"BIHAR"', '"GOPALGANJ"', 2001, 0, 0),
#  ('"BIHAR"', '"JAMALPUR RLY."', 2001, 0, 0),
#  ('"BIHAR"', '"JAMUI"', 2001, 0, 0),
#  ('"BIHAR"', '"JEHANABAD"', 2001, 0, 0),
#  ('"BIHAR"', '"KATIHAR"', 2001, 0, 0),
#  ('"BIHAR"', '"KATIHAR RLY."', 2001, 0, 0),
#  ('"BIHAR"', '"KHAGARIA"', 2001, 0, 0),
#  ('"BIHAR"', '"KISHANGANJ"', 2001, 2, 0),
#  ('"BIHAR"', '"LAKHISARAI"', 2001, 1, 0),
#  ('"BIHAR"', '"MADHEPURA"', 2001, 0, 0),
#  ('"BIHAR"', '"MADHUBANI"', 2001, 0, 0),
#  ('"BIHAR"', '"MOTIHARI"', 2001, 0, 0),
#  ('"BIHAR"', '"MUNGER"', 2001, 0, 0),
#  ('"BIHAR"', '"MUZAFFARPUR"', 2001, 0, 0),
#  ('"BIHAR"', '"MUZAFFARPUR RLY."', 2001, 0, 0),
#  ('"BIHAR"', '"NALANDA"', 2001, 0, 0),
#  ('"BIHAR"', '"NAUGACHIA"', 2001, 0, 0),
#  ('"BIHAR"', '"NAWADAH"', 2001, 0, 0),
#  ('"BIHAR"', '"PATNA"', 2001, 0, 0),
#  ('"BIHAR"', '"PATNA RLY."', 2001, 0, 0),
#  ('"BIHAR"', '"PURNEA"', 2001, 0, 0),
#  ('"BIHAR"', '"ROHTAS"', 2001, 0, 0),
#  ('"BIHAR"', '"SAHARSA"', 2001, 0, 0),
#  ('"BIHAR"', '"SAMASTIPUR"', 2001, 0, 0),
#  ('"BIHAR"', '"SARAN"', 2001, 0, 0),
#  ('"BIHAR"', '"SHEIKHPURA"', 2001, 0, 0),
#  ('"BIHAR"', '"SHEOHAR"', 2001, 0, 0),
#  ('"BIHAR"', '"SITAMARHI"', 2001, 0, 0),
#  ('"BIHAR"', '"SIWAN"', 2001, 0, 0),
#  ('"BIHAR"', '"SUPAUL"', 2001, 0, 0),
#  ('"BIHAR"', '"VAISHALI"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"BALRAMPUR"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"BIZAPUR"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"DANTEWARA"', 2001, 5, 0),
#  ('"CHHATTISGARH"', '"DHAMTARI"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"DURG"', 2001, 12, 0),
#  ('"CHHATTISGARH"', '"GRP RAIPUR"', 2001, 0, 0),
#  ('"CHHATTISGARH"', '"JASHPUR"', 2001, 4, 0),
#  ('"CHHATTISGARH"', '"KORIYA"', 2001, 1, 0),
#  ('"CHHATTISGARH"', '"MAHASAMUND"', 2001, 3, 0),
#  ('"CHHATTISGARH"', '"RAIGARH"', 2001, 7, 0),
#  ('"CHHATTISGARH"', '"RAIPUR"', 2001, 7, 0),
#  ('"CHHATTISGARH"', '"RAJNANDGAON"', 2001, 0, 0),
#  ('"GOA"', '"NORTH GOA"', 2001, 0, 0),
#  ('"GOA"', '"SOUTH GOA"', 2001, 0, 0),
#  ('"GOA"', '"TOTAL"', 2001, 0, 0),
#  ('"GUJARAT"', '"AHMEDABAD COMMR."', 2001, 0, 0),
#  ('"GUJARAT"', '"AHMEDABAD RURAL"', 2001, 0, 0),
#  ('"GUJARAT"', '"AHWA-DANG"', 2001, 1, 0),
#  ('"GUJARAT"', '"AMRELI"', 2001, 0, 0),
#  ('"GUJARAT"', '"ANAND"', 2001, 0, 0),
#  ('"GUJARAT"', '"BHARUCH"', 2001, 2, 0),
#  ('"GUJARAT"', '"BHAVNAGAR"', 2001, 0, 0),
#  ('"GUJARAT"', '"DAHOD"', 2001, 0, 0),
#  ('"GUJARAT"', '"GANDHINAGAR"', 2001, 0, 0),
#  ('"GUJARAT"', '"HIMATNAGAR"', 2001, 1, 0),
#  ('"GUJARAT"', '"JAMNAGAR"', 2001, 1, 0),
#  ('"GUJARAT"', '"JUNAGADH"', 2001, 0, 0),
#  ('"GUJARAT"', '"KHEDA NORTH"', 2001, 0, 0),
#  ('"GUJARAT"', '"KUTCH"', 2001, 0, 0),
#  ('"GUJARAT"', '"MEHSANA"', 2001, 0, 0),
#  ('"GUJARAT"', '"NARMADA"', 2001, 1, 0),
#  ('"GUJARAT"', '"NAVSARI"', 2001, 2, 0),
#  ('"GUJARAT"', '"PATAN"', 2001, 1, 0),
#  ('"GUJARAT"', '"PORBANDAR"', 2001, 0, 0),
#  ('"GUJARAT"', '"RAJKOT COMMR."', 2001, 0, 0),
#  ('"GUJARAT"', '"RAJKOT RURAL"', 2001, 0, 0),
#  ('"GUJARAT"', '"SURAT COMMR."', 2001, 2, 0),
#  ('"GUJARAT"', '"SURENDRANAGAR"', 2001, 1, 0),
#  ('"GUJARAT"', '"VALSAD"', 2001, 1, 0),
#  ('"GUJARAT"', '"W.RLY"', 2001, 0, 0),
#  ('"HARYANA"', '"AMBALA"', 2001, 0, 0),
#  ('"HARYANA"', '"BHIWANI"', 2001, 0, 0),
#  ('"HARYANA"', '"FARIDABAD"', 2001, 0, 0),
#  ('"HARYANA"', '"FATEHABAD"', 2001, 0, 0),
#  ('"HARYANA"', '"GRP"', 2001, 0, 0),
#  ('"HARYANA"', '"GURGAON"', 2001, 0, 0),
#  ('"HARYANA"', '"HISAR"', 2001, 0, 0),
#  ('"HARYANA"', '"JHAJJAR"', 2001, 0, 0),
#  ('"HARYANA"', '"JIND"', 2001, 0, 0),
#  ('"HARYANA"', '"KAITHAL"', 2001, 0, 0),
#  ('"HARYANA"', '"KARNAL"', 2001, 0, 0),
#  ('"HARYANA"', '"KURUKSHETRA"', 2001, 0, 0),
#  ('"HARYANA"', '"MAHENDERGARH"', 2001, 0, 0),
#  ('"HARYANA"', '"PANCHKULA"', 2001, 0, 0),
#  ('"HARYANA"', '"PANIPAT"', 2001, 0, 0),
#  ('"HARYANA"', '"REWARI"', 2001, 0, 0),
#  ('"HARYANA"', '"ROHTAK"', 2001, 0, 0),
#  ('"HARYANA"', '"SIRSA"', 2001, 0, 0),
#  ('"HARYANA"', '"SONIPAT"', 2001, 0, 0),
#  ('"HARYANA"', '"YAMUNANAGAR"', 2001, 0, 0),
#  ('"HARYANA"', '"TOTAL"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"BILASPUR"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CHAMBA"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"HAMIRPUR"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KANGRA"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KINNAUR"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KULLU"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"MANDI"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"SHIMLA"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"SIRMAUR"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"SOLAN"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"UNA"', 2001, 0, 0),
#  ('"HIMACHAL PRADESH"', '"TOTAL"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"ANANTNAG"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"ANANTNAG"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"AWANTIPORA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BARAMULLA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BORDER"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BUDGAM"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"DODA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"GANDERBAL"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"JAMMU"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KARGIL"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KATHUA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KULGAM"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KUPWARA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"LEH"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"POONCH"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"PULWAMA"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAJOURI"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAMBAN"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"REASI"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"SRINAGAR"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"UDHAMPUR"', 2001, 0, 0),
#  ('"JAMMU & KASHMIR"', '"TOTAL"', 2001, 0, 0),
#  ('"JHARKHAND"', '"BOKARO"', 2001, 0, 0),
#  ('"JHARKHAND"', '"CHAIBASA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"DEOGHAR"', 2001, 0, 0),
#  ('"JHARKHAND"', '"DHANBAD"', 2001, 1, 0),
#  ('"JHARKHAND"', '"DHANBAD RLY."', 2001, 0, 0),
#  ('"JHARKHAND"', '"DUMKA"', 2001, 1, 0),
#  ('"JHARKHAND"', '"GARHWA"', 2001, 1, 0),
#  ('"JHARKHAND"', '"GIRIDIH"', 2001, 0, 0),
#  ('"JHARKHAND"', '"GODDA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"GUMALA"', 2001, 1, 0),
#  ('"JHARKHAND"', '"HAZARIBAGH"', 2001, 0, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR"', 2001, 4, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR RLY."', 2001, 0, 0),
#  ('"JHARKHAND"', '"JAMTARA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"KODERMA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"LATEHAR"', 2001, 0, 0),
#  ('"JHARKHAND"', '"LOHARDAGGA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"PAKUR"', 2001, 0, 0),
#  ('"JHARKHAND"', '"PALAMU"', 2001, 1, 0),
#  ('"JHARKHAND"', '"SARAIKELA"', 2001, 0, 0),
#  ('"JHARKHAND"', '"SIMDEGA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BAGALKOT"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BANGALORE COMMR."', 2001, 0, 0),
#  ('"KARNATAKA"', '"BANGALORE RURAL"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BELGAUM"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BELLARY"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BIDAR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"BIJAPUR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"CHAMARAJNAGAR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"CHICKMAGALUR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"CHITRADURGA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"DAKSHIN KANNADA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"DAVANAGERE"', 2001, 1, 0),
#  ('"KARNATAKA"', '"DHARWAD COMMR."', 2001, 0, 0),
#  ('"KARNATAKA"', '"DHARWAD RURAL"', 2001, 0, 0),
#  ('"KARNATAKA"', '"GADAG"', 2001, 0, 0),
#  ('"KARNATAKA"', '"GULBARGA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"HASSAN"', 2001, 0, 0),
#  ('"KARNATAKA"', '"HAVERI"', 2001, 0, 0),
#  ('"KARNATAKA"', '"K.G.F."', 2001, 0, 0),
#  ('"KARNATAKA"', '"KOLAR"', 2001, 1, 0),
#  ('"KARNATAKA"', '"KOPPAL"', 2001, 0, 0),
#  ('"KARNATAKA"', '"MANDYA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"MYSORE COMMR."', 2001, 0, 0),
#  ('"KARNATAKA"', '"MYSORE RURAL"', 2001, 0, 0),
#  ('"KARNATAKA"', '"RAICHUR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2001, 0, 0),
#  ('"KARNATAKA"', '"SHIMOGA"', 2001, 0, 0),
#  ('"KARNATAKA"', '"TUMKUR"', 2001, 0, 0),
#  ('"KARNATAKA"', '"UDUPI"', 2001, 0, 0),
#  ('"KARNATAKA"', '"UTTAR KANNADA"', 2001, 0, 0),
#  ('"KERALA"', '"ALAPUZHA"', 2001, 0, 0),
#  ('"KERALA"', '"CBCID"', 2001, 0, 0),
#  ('"KERALA"', '"ERNAKULAM"', 2001, 1, 0),
#  ('"KERALA"', '"IDUKKI"', 2001, 2, 0),
#  ('"KERALA"', '"KASARGOD"', 2001, 0, 0),
#  ('"KERALA"', '"KOLLAM"', 2001, 2, 0),
#  ('"KERALA"', '"KOTTAYAM"', 2001, 0, 0),
#  ('"KERALA"', '"KOZHIKODE"', 2001, 2, 0),
#  ('"KERALA"', '"MALAPPURAM"', 2001, 0, 0),
#  ('"KERALA"', '"PATHANAMTHITTA"', 2001, 0, 0),
#  ('"KERALA"', '"RAILWAYS"', 2001, 0, 0),
#  ('"KERALA"', '"TRIVANDRUM"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"BETUL"', 2001, 15, 0),
#  ('"MADHYA PRADESH"', '"BHIND"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"BHOPAL RLY."', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"CHHATARPUR"', 2001, 6, 0),
#  ('"MADHYA PRADESH"', '"DAMOH"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"DATIYA"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"DEWAS"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"DINDORI"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"HARDA"', 2001, 5, 0),
#  ('"MADHYA PRADESH"', '"INDORE"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"INDORE RLY."', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"JHABUA"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"KATNI"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"KHARGON"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"MANDSAUR"', 2001, 2, 0),
#  ('"MADHYA PRADESH"', '"MORENA"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"NARSINGHPUR"', 2001, 8, 0),
#  ('"MADHYA PRADESH"', '"NEEMUCH"', 2001, 3, 0),
#  ('"MADHYA PRADESH"', '"RAISEN"', 2001, 0, 0),
#  ('"MADHYA PRADESH"', '"REWA"', 2001, 5, 0),
#  ('"MADHYA PRADESH"', '"SATNA"', 2001, 5, 0),
#  ('"MADHYA PRADESH"', '"SEONI"', 2001, 12, 0),
#  ('"MADHYA PRADESH"', '"SHAHDOL"', 2001, 9, 0),
#  ('"MADHYA PRADESH"', '"SHAJAPUR"', 2001, 2, 0),
#  ('"MADHYA PRADESH"', '"SIDHI"', 2001, 3, 0),
#  ('"MADHYA PRADESH"', '"UJJAIN"', 2001, 1, 0),
#  ('"MADHYA PRADESH"', '"UMARIYA"', 2001, 3, 0),
#  ('"MADHYA PRADESH"', '"VIDISHA"', 2001, 8, 0),
#  ('"MAHARASHTRA"', '"AKOLA"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI RURAL"', 2001, 3, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD RURAL"', 2001, 1, 0),
#  ('"MAHARASHTRA"', '"BEED"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"BHANDARA"', 2001, 1, 0),
#  ('"MAHARASHTRA"', '"BULDHANA"', 2001, 2, 0),
#  ('"MAHARASHTRA"', '"CHANDRAPUR"', 2001, 6, 0),
#  ('"MAHARASHTRA"', '"GADCHIROLI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"GONDIA"', 2001, 1, 0),
#  ('"MAHARASHTRA"', '"HINGOLI"', 2001, 1, 0),
#  ('"MAHARASHTRA"', '"JALGAON"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"JALNA"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"KOLHAPUR"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"LATUR"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"MUMBAI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"MUMBAI RLY."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"NAGPUR COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"NAGPUR RURAL"', 2001, 2, 0),
#  ('"MAHARASHTRA"', '"NANDED"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"NANDURBAR"', 2001, 1, 0),
#  ('"MAHARASHTRA"', '"NASIK COMMR."', 2001, 3, 0),
#  ('"MAHARASHTRA"', '"NAVI MUMBAI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"OSMANABAD"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"PARBHANI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"RAIGAD"', 2001, 2, 0),
#  ('"MAHARASHTRA"', '"RATNAGIRI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"SANGLI"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"SATARA"', 2001, 3, 0),
#  ('"MAHARASHTRA"', '"SINDHUDURG"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR RURAL"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"THANE COMMR."', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"THANE RURAL"', 2001, 9, 0),
#  ('"MAHARASHTRA"', '"WARDHA"', 2001, 2, 0),
#  ('"MAHARASHTRA"', '"WASHIM"', 2001, 0, 0),
#  ('"MAHARASHTRA"', '"YAVATMAL"', 2001, 6, 0),
#  ('"MANIPUR"', '"BISHNUPUR"', 2001, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2001, 0, 0),
#  ('"MANIPUR"', '"CHURACHANDPUR"', 2001, 0, 0),
#  ('"MANIPUR"', '"IMPHAL(EAST)"', 2001, 0, 0),
#  ('"MANIPUR"', '"IMPHAL(WEST)"', 2001, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2001, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2001, 0, 0),
#  ('"MANIPUR"', '"THOUBAL"', 2001, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2001, 0, 0),
#  ('"MANIPUR"', '"TOTAL"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS EAST"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS WEST"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"JAINTIA HILLS"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS EAST"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS WEST"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"RI-BHOI"', 2001, 0, 0),
#  ('"MEGHALAYA"', '"TOTAL"', 2001, 0, 0),
#  ('"MIZORAM"', '"AIZAWL"', 2001, 0, 0),
#  ('"MIZORAM"', '"CHAMPHAI"', 2001, 1, 0),
#  ('"MIZORAM"', '"KOLASIB"', 2001, 1, 0),
#  ('"MIZORAM"', '"LAWNGTLAI"', 2001, 0, 0),
#  ('"MIZORAM"', '"LUNGLEI"', 2001, 0, 0),
#  ('"MIZORAM"', '"MAMIT"', 2001, 0, 0),
#  ('"MIZORAM"', '"SAIHA"', 2001, 0, 0),
#  ('"MIZORAM"', '"SERCHHIP"', 2001, 0, 0),
#  ('"MIZORAM"', '"TOTAL"', 2001, 2, 0),
#  ('"NAGALAND"', '"DIMAPUR"', 2001, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2001, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2001, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2001, 0, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2001, 0, 0),
#  ('"ODISHA"', '"ANGUL"', 2001, 0, 0),
#  ('"ODISHA"', '"BALASORE"', 2001, 0, 0),
#  ('"ODISHA"', '"BARAGARH"', 2001, 0, 0),
#  ('"ODISHA"', '"BERHAMPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"BHADRAK"', 2001, 0, 0),
#  ('"ODISHA"', '"BOUDH"', 2001, 0, 0),
#  ('"ODISHA"', '"CUTTACK"', 2001, 0, 0),
#  ('"ODISHA"', '"DEOGARH"', 2001, 1, 0),
#  ('"ODISHA"', '"DHENKANAL"', 2001, 0, 0),
#  ('"ODISHA"', '"GANJAM"', 2001, 0, 0),
#  ('"ODISHA"', '"JAGATSINGHPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"JAJPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"JHARSUGUDA"', 2001, 1, 0),
#  ('"ODISHA"', '"KALAHANDI"', 2001, 1, 0),
#  ('"ODISHA"', '"KANDHAMAL"', 2001, 1, 0),
#  ('"ODISHA"', '"KENDRAPARA"', 2001, 0, 0),
#  ('"ODISHA"', '"KEONJHAR"', 2001, 3, 0),
#  ('"ODISHA"', '"KHURDA"', 2001, 0, 0),
#  ('"ODISHA"', '"KORAPUT"', 2001, 2, 0),
#  ('"ODISHA"', '"MALKANGIR"', 2001, 2, 0),
#  ('"ODISHA"', '"MAYURBHANJ"', 2001, 9, 0),
#  ('"ODISHA"', '"NAYAGARH"', 2001, 0, 0),
#  ('"ODISHA"', '"NOWRANGPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"NUAPADA"', 2001, 0, 0),
#  ('"ODISHA"', '"PURI"', 2001, 0, 0),
#  ('"ODISHA"', '"RAYAGADA"', 2001, 0, 0),
#  ('"ODISHA"', '"ROURKELA"', 2001, 0, 0),
#  ('"ODISHA"', '"SAMBALPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"SONEPUR"', 2001, 0, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2001, 0, 0),
#  ('"ODISHA"', '"SRP(ROURKELA)"', 2001, 0, 0),
#  ('"PUNJAB"', '"AMRITSAR"', 2001, 0, 0),
#  ('"PUNJAB"', '"BARNALA"', 2001, 0, 0),
#  ('"PUNJAB"', '"BATALA"', 2001, 0, 0),
#  ('"PUNJAB"', '"BHATINDA"', 2001, 0, 0),
#  ('"PUNJAB"', '"FARIDKOT"', 2001, 0, 0),
#  ('"PUNJAB"', '"FATEHGARH SAHIB"', 2001, 0, 0),
#  ('"PUNJAB"', '"FEROZEPUR"', 2001, 0, 0),
#  ('"PUNJAB"', '"G.R.P"', 2001, 0, 0),
#  ('"PUNJAB"', '"GURDASPUR"', 2001, 0, 0),
#  ('"PUNJAB"', '"HOSHIARPUR"', 2001, 0, 0),
#  ('"PUNJAB"', '"JAGRAON"', 2001, 0, 0),
#  ('"PUNJAB"', '"JALANDHAR"', 2001, 0, 0),
#  ('"PUNJAB"', '"KAPURTHALA"', 2001, 0, 0),
#  ('"PUNJAB"', '"KHANNA"', 2001, 0, 0),
#  ('"PUNJAB"', '"LUDHIANA"', 2001, 0, 0),
#  ('"PUNJAB"', '"MAJITHA"', 2001, 0, 0),
#  ('"PUNJAB"', '"MANSA"', 2001, 0, 0),
#  ('"PUNJAB"', '"MOGA"', 2001, 0, 0),
#  ('"PUNJAB"', '"MUKTSAR"', 2001, 0, 0),
#  ('"PUNJAB"', '"NAWAN SHAHR"', 2001, 0, 0),
#  ('"PUNJAB"', '"PATIALA"', 2001, 0, 0),
#  ('"PUNJAB"', '"ROPAR"', 2001, 0, 0),
#  ('"PUNJAB"', '"SANGRUR"', 2001, 0, 0),
#  ('"PUNJAB"', '"TARN TARAN"', 2001, 0, 0),
#  ('"PUNJAB"', '"TOTAL"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"AJMER"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"ALWAR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"BANSWARA"', 2001, 4, 0),
#  ('"RAJASTHAN"', '"BARMER"', 2001, 1, 0),
#  ('"RAJASTHAN"', '"BHARATPUR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"BHILWARA"', 2001, 2, 0),
#  ('"RAJASTHAN"', '"BIKANER"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"BUNDI"', 2001, 2, 0),
#  ('"RAJASTHAN"', '"CHITTORGARH"', 2001, 5, 0),
#  ('"RAJASTHAN"', '"CHURU"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"DUNGARPUR"', 2001, 4, 0),
#  ('"RAJASTHAN"', '"G.R.P."', 2001, 0, 0),
#  ('"RAJASTHAN"', '"GANGANAGAR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"HANUMANGARH"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"JAISALMER"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"JALORE"', 2001, 1, 0),
#  ('"RAJASTHAN"', '"JODHPUR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"KARAULI"', 2001, 2, 0),
#  ('"RAJASTHAN"', '"NAGAUR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"RAJSAMAND"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"SAWAI MADHOPUR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"SIKAR"', 2001, 0, 0),
#  ('"RAJASTHAN"', '"TONK"', 2001, 0, 0),
#  ('"SIKKIM"', '"NORTH"', 2001, 0, 0),
#  ('"SIKKIM"', '"WEST"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"ARIYALUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"CHENGAI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2001, 0, 0),
#  ('"TAMIL NADU"', '"COIMBATORE RURAL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"COIMBATORE URBAN"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"CUDDALORE"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"DHARMAPURI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"DINDIGUL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"ERODE"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"KANCHIPURAM"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"KANYAKUMARI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"KARUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"MADURAI RURAL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"MADURAI URBAN"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"NAGAPATTINAM"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"NAMAKKAL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"NILGIRIS"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"PERAMBALUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"PUDUKOTTAI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"RAMNATHAPURAM"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"SALEM RURAL"', 2001, 1, 0),
#  ('"TAMIL NADU"', '"SALEM URBAN"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"SIVAGANGAI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THANJAVUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THENI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THIRUNELVELI RURAL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THIRUNELVELI URBAN"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THIRUVALLUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THIRUVANNAMALAI"', 2001, 1, 0),
#  ('"TAMIL NADU"', '"THIRUVARUR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"THOOTHUGUDI"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2001, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY RURAL"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"TRICHY URBAN"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"VELLORE"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"VILLUPURAM"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"VIRUDHUNAGAR"', 2001, 0, 0),
#  ('"TAMIL NADU"', '"TOTAL"', 2001, 2, 0),
#  ('"TRIPURA"', '"DHALAI"', 2001, 0, 0),
#  ('"TRIPURA"', '"NORTH"', 2001, 0, 0),
#  ('"TRIPURA"', '"SOUTH"', 2001, 0, 0),
#  ('"TRIPURA"', '"WEST"', 2001, 0, 0),
#  ('"TRIPURA"', '"TOTAL"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"AGRA"', 2001, 1, 0),
#  ('"UTTAR PRADESH"', '"ALLAHABAD"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"AMBEDKAR NAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"AURAIYA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"AZAMGARH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BADAUN"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BAGHPAT"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BAHRAICH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BALLIA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BALRAMPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BANDA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BARABANKI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BAREILLY"', 2001, 1, 0),
#  ('"UTTAR PRADESH"', '"BASTI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BIJNOR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"BULANDSHAHAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"CHANDOLI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"CHITRAKOOT DHAM"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"DEORIA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"ETAH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"ETAWAH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"FAIZABAD"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"FATEHGARH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"FATEHPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"FIROZABAD"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"G.R.P."', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"GAUTAMBUDH NAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"GHAZIABAD"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"GHAZIPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"GONDA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"GORAKHPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"HAMIRPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"HARDOI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"HATHRAS"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"J.P.NAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"JALAUN"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"JAUNPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"JHANSI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KANNAUJ"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KANPUR DEHAT"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KANPUR NAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KAUSHAMBI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KHIRI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"KUSHI NAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"LALITPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"LUCKNOW"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MAHARAJGANJ"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MAHOBA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MAINPURI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MATHURA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MAU"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MEERUT"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MIRZAPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"MUZAFFARNAGAR"', 2001, 1, 0),
#  ('"UTTAR PRADESH"', '"PILIBHIT"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"PRATAPGARH"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"RAIBAREILLY"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"RAMPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SAHARANPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SANT KABIRNAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SHAHJAHANPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SHRAWASTI"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SIDHARTHNAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SITAPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SONBHADRA"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"ST.RAVIDASNAGAR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"SULTANPUR"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"UNNAO"', 2001, 0, 0),
#  ('"UTTAR PRADESH"', '"VARANASI"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"ALMORA"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"BAGESHWAR"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"CHAMOLI"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"CHAMPAWAT"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"DEHRADUN"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"HARIDWAR"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"NAINITAL"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"PAURI GARHWAL"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"PITHORAGARH"', 2001, 1, 0),
#  ('"UTTARAKHAND"', '"RUDRA PRAYAG"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"TEHRI GARHWAL"', 2001, 0, 0),
#  ('"UTTARAKHAND"', '"UTTARKASHI"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"24 PARGANAS NORTH"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"24 PARGANAS SOUTH"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"ASANSOL"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"BANKURA"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"BIRBHUM"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"BURDWAN"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"COOCHBEHAR"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"DAKSHIN DINAJPUR"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"DARJEELING"', 2001, 1, 0),
#  ('"WEST BENGAL"', '"HOOGHLY"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"HOWRAH"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"HOWRAH CITY"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"HOWRAH G.R.P."', 2001, 0, 0),
#  ('"WEST BENGAL"', '"JALPAIGURI"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"KOLKATA"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"MALDA"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"MIDNAPUR"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"MURSHIDABAD"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"NADIA"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"PURULIA"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"SEALDAH G.R.P."', 2001, 0, 0),
#  ('"WEST BENGAL"', '"SILIGURI G.R.P."', 2001, 0, 0),
#  ('"WEST BENGAL"', '"UTTAR DINAJPUR"', 2001, 0, 0),
#  ('"WEST BENGAL"', '"TOTAL"', 2001, 1, 0),
#  ('"A & N ISLANDS"', '"ANDAMAN"', 2001, 0, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2001, 0, 0),
#  ('"A & N ISLANDS"', '"TOTAL"', 2001, 0, 0),
#  ('"CHANDIGARH"', '"CHANDIGARH"', 2001, 0, 0),
#  ('"CHANDIGARH"', '"TOTAL"', 2001, 0, 0),
#  ('"D & N HAVELI"', '"D and N HAVELI"', 2001, 0, 0),
#  ('"D & N HAVELI"', '"TOTAL"', 2001, 0, 0),
#  ('"DAMAN & DIU"', '"DAMAN"', 2001, 0, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2001, 0, 0),
#  ('"DAMAN & DIU"', '"TOTAL"', 2001, 0, 0),
#  ('"DELHI"', '"CENTRAL"', 2001, 0, 0),
#  ('"DELHI"', '"EAST"', 2001, 0, 0),
#  ('"DELHI"', '"G.R.P.(RLY)"', 2001, 0, 0),
#  ('"DELHI"', '"I.G.I.AIRPORT"', 2001, 0, 0),
#  ('"DELHI"', '"NEW DELHI"', 2001, 0, 0),
#  ('"DELHI"', '"NORTH"', 2001, 0, 0),
#  ('"DELHI"', '"NORTH EAST"', 2001, 0, 0),
#  ('"DELHI"', '"NORTH WEST"', 2001, 0, 0),
#  ('"DELHI"', '"S.T.F."', 2001, 0, 0),
#  ('"DELHI"', '"SOUTH"', 2001, 0, 0),
#  ('"DELHI"', '"SOUTH WEST"', 2001, 0, 0),
#  ('"DELHI"', '"WEST"', 2001, 0, 0),
#  ('"DELHI"', '"TOTAL"', 2001, 0, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2001, 0, 0),
#  ('"LAKSHADWEEP"', '"TOTAL"', 2001, 0, 0),
#  ('"PUDUCHERRY"', '"PONDICHERRY"', 2001, 0, 0),
#  ('"PUDUCHERRY"', '"TOTAL"', 2001, 0, 0),
#  ('"ANDHRA PRADESH"', '"ADILABAD"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"ANANTAPUR"', 2002, 1, 0),
#  ('"ANDHRA PRADESH"', '"CHITTOOR"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"CUDDAPAH"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"EAST GODAVARI"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"GUNTUR"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"HYDERABAD CITY"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"KHAMMAM"', 2002, 8, 0),
#  ('"ANDHRA PRADESH"', '"KRISHNA"', 2002, 1, 0),
#  ('"ANDHRA PRADESH"', '"KURNOOL"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"MEDAK"', 2002, 2, 0),
#  ('"ANDHRA PRADESH"', '"NALGONDA"', 2002, 1, 0),
#  ('"ANDHRA PRADESH"', '"NELLORE"', 2002, 1, 0),
#  ('"ANDHRA PRADESH"', '"NIZAMABAD"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"PRAKASHAM"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"RANGA REDDY"', 2002, 2, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"SRIKAKULAM"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHA RURAL"', 2002, 1, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHAPATNAM"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"VIZIANAGARAM"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"WARANGAL"', 2002, 0, 0),
#  ('"ANDHRA PRADESH"', '"WEST GODAVARI"', 2002, 1, 0),
#  ('"ARUNACHAL PRADESH"', '"DIBANG VALLEY"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG EAST"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG WEST"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"LOHIT"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG EAST"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG UPPER"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG WEST"', 2002, 1, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI LOWER"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI UPPER"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2002, 0, 0),
#  ('"ARUNACHAL PRADESH"', '"TIRAP"', 2002, 0, 0),
#  ('"ASSAM"', '"BARPETA"', 2002, 0, 0),
#  ('"ASSAM"', '"BONGAIGAON"', 2002, 0, 0),
#  ('"ASSAM"', '"C.I.D."', 2002, 0, 0),
#  ('"ASSAM"', '"CACHAR"', 2002, 0, 0),
#  ('"ASSAM"', '"DARRANG"', 2002, 0, 0),
#  ('"ASSAM"', '"DHEMAJI"', 2002, 0, 0),
#  ('"ASSAM"', '"DHUBRI"', 2002, 0, 0),
#  ('"ASSAM"', '"DIBRUGARH"', 2002, 0, 0),
#  ('"ASSAM"', '"G.R.P."', 2002, 0, 0),
#  ('"ASSAM"', '"GOALPARA"', 2002, 0, 0),
#  ('"ASSAM"', '"GUWAHATI CITY"', 2002, 0, 0),
#  ('"ASSAM"', '"HAILAKANDI"', 2002, 0, 0),
#  ('"ASSAM"', '"JORHAT"', 2002, 0, 0),
#  ('"ASSAM"', '"KAMRUP"', 2002, 0, 0),
#  ('"ASSAM"', '"KARBI ANGLONG"', 2002, 0, 0),
#  ('"ASSAM"', '"KARIMGANJ"', 2002, 0, 0),
#  ('"ASSAM"', '"KOKRAJHAR"', 2002, 0, 0),
#  ('"ASSAM"', '"LAKHIMPUR"', 2002, 0, 0),
#  ('"ASSAM"', '"MORIGAON"', 2002, 0, 0),
#  ('"ASSAM"', '"NAGAON"', 2002, 0, 0),
#  ('"ASSAM"', '"NALBARI"', 2002, 0, 0),
#  ('"ASSAM"', '"R.P.O."', 2002, 0, 0),
#  ('"ASSAM"', '"SIBSAGAR"', 2002, 0, 0),
#  ('"ASSAM"', '"SONITPUR"', 2002, 0, 0),
#  ('"ASSAM"', '"TINSUKIA"', 2002, 0, 0),
#  ('"BIHAR"', '"ARWAL"', 2002, 0, 0),
#  ('"BIHAR"', '"AURANGABAD"', 2002, 0, 0),
#  ('"BIHAR"', '"BAGAHA"', 2002, 0, 0),
#  ('"BIHAR"', '"BANKA"', 2002, 0, 0),
#  ('"BIHAR"', '"BEGUSARAI"', 2002, 0, 0),
#  ('"BIHAR"', '"BETTIAH"', 2002, 0, 0),
#  ('"BIHAR"', '"BHABHUA"', 2002, 0, 0),
#  ('"BIHAR"', '"BHAGALPUR"', 2002, 0, 0),
#  ('"BIHAR"', '"BHOJPUR"', 2002, 0, 0),
#  ('"BIHAR"', '"BUXAR"', 2002, 0, 0),
#  ('"BIHAR"', '"DARBHANGA"', 2002, 0, 0),
#  ('"BIHAR"', '"GAYA"', 2002, 0, 0),
#  ('"BIHAR"', '"GOPALGANJ"', 2002, 0, 0),
#  ('"BIHAR"', '"JAMALPUR RLY."', 2002, 0, 0),
#  ('"BIHAR"', '"JAMUI"', 2002, 0, 0),
#  ('"BIHAR"', '"KATIHAR"', 2002, 0, 0),
#  ('"BIHAR"', '"KATIHAR RLY."', 2002, 0, 0),
#  ('"BIHAR"', '"KHAGARIA"', 2002, 0, 0),
#  ('"BIHAR"', '"KISHANGANJ"', 2002, 0, 0),
#  ('"BIHAR"', '"LAKHISARAI"', 2002, 0, 0),
#  ('"BIHAR"', '"MADHEPURA"', 2002, 0, 0),
#  ('"BIHAR"', '"MADHUBANI"', 2002, 0, 0),
#  ('"BIHAR"', '"MOTIHARI"', 2002, 0, 0),
#  ('"BIHAR"', '"MUNGER"', 2002, 0, 0),
#  ('"BIHAR"', '"MUZAFFARPUR"', 2002, 0, 0),
#  ('"BIHAR"', '"MUZAFFARPUR RLY."', 2002, 0, 0),
#  ('"BIHAR"', '"NALANDA"', 2002, 0, 0),
#  ('"BIHAR"', '"NAUGACHIA"', 2002, 0, 0),
#  ('"BIHAR"', '"NAWADAH"', 2002, 0, 0),
#  ('"BIHAR"', '"PATNA"', 2002, 0, 0),
#  ('"BIHAR"', '"PATNA RLY."', 2002, 0, 0),
#  ('"BIHAR"', '"PURNEA"', 2002, 0, 0),
#  ('"BIHAR"', '"ROHTAS"', 2002, 0, 0),
#  ('"BIHAR"', '"SAHARSA"', 2002, 0, 0),
#  ('"BIHAR"', '"SAMASTIPUR"', 2002, 0, 0),
#  ('"BIHAR"', '"SARAN"', 2002, 0, 0),
#  ('"BIHAR"', '"SHEIKHPURA"', 2002, 0, 0),
#  ('"BIHAR"', '"SHEOHAR"', 2002, 0, 0),
#  ('"BIHAR"', '"SITAMARHI"', 2002, 0, 0),
#  ('"BIHAR"', '"SIWAN"', 2002, 0, 0),
#  ('"BIHAR"', '"SUPAUL"', 2002, 0, 0),
#  ('"BIHAR"', '"VAISHALI"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"BALRAMPUR"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"BIZAPUR"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"DANTEWARA"', 2002, 1, 0),
#  ('"CHHATTISGARH"', '"DHAMTARI"', 2002, 1, 0),
#  ('"CHHATTISGARH"', '"GRP RAIPUR"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"JASHPUR"', 2002, 6, 0),
#  ('"CHHATTISGARH"', '"KABIRDHAM"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"MAHASAMUND"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"RAIGARH"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"RAIPUR"', 2002, 10, 0),
#  ('"CHHATTISGARH"', '"RAJNANDGAON"', 2002, 0, 0),
#  ('"CHHATTISGARH"', '"SARGUJA"', 2002, 3, 0),
#  ('"GOA"', '"NORTH GOA"', 2002, 0, 0),
#  ('"GOA"', '"SOUTH GOA"', 2002, 0, 0),
#  ('"GOA"', '"TOTAL"', 2002, 0, 0),
#  ('"GUJARAT"', '"AHMEDABAD RURAL"', 2002, 0, 0),
#  ('"GUJARAT"', '"AHWA-DANG"', 2002, 0, 0),
#  ('"GUJARAT"', '"AMRELI"', 2002, 0, 0),
#  ('"GUJARAT"', '"ANAND"', 2002, 0, 0),
#  ('"GUJARAT"', '"BHARUCH"', 2002, 1, 0),
#  ('"GUJARAT"', '"BHAVNAGAR"', 2002, 0, 0),
#  ('"GUJARAT"', '"DAHOD"', 2002, 0, 0),
#  ('"GUJARAT"', '"GANDHINAGAR"', 2002, 0, 0),
#  ('"GUJARAT"', '"HIMATNAGAR"', 2002, 0, 0),
#  ('"GUJARAT"', '"JAMNAGAR"', 2002, 3, 0),
#  ('"GUJARAT"', '"JUNAGADH"', 2002, 0, 0),
#  ('"GUJARAT"', '"KHEDA NORTH"', 2002, 0, 0),
#  ('"GUJARAT"', '"MEHSANA"', 2002, 0, 0),
#  ('"GUJARAT"', '"NARMADA"', 2002, 0, 0),
#  ('"GUJARAT"', '"NAVSARI"', 2002, 0, 0),
#  ('"GUJARAT"', '"PATAN"', 2002, 0, 0),
#  ('"GUJARAT"', '"PORBANDAR"', 2002, 0, 0),
#  ('"GUJARAT"', '"RAJKOT COMMR."', 2002, 0, 0),
#  ('"GUJARAT"', '"RAJKOT RURAL"', 2002, 0, 0),
#  ('"GUJARAT"', '"SURAT COMMR."', 2002, 0, 0),
#  ('"GUJARAT"', '"VADODARA COMMR."', 2002, 0, 0),
#  ('"GUJARAT"', '"W.RLY"', 2002, 1, 0),
#  ('"HARYANA"', '"AMBALA"', 2002, 0, 0),
#  ('"HARYANA"', '"BHIWANI"', 2002, 0, 0),
#  ('"HARYANA"', '"FARIDABAD"', 2002, 0, 0),
#  ('"HARYANA"', '"FATEHABAD"', 2002, 0, 0),
#  ('"HARYANA"', '"GRP"', 2002, 0, 0),
#  ('"HARYANA"', '"GURGAON"', 2002, 0, 0),
#  ('"HARYANA"', '"HISSAR"', 2002, 0, 0),
#  ('"HARYANA"', '"JHAJJAR"', 2002, 0, 0),
#  ('"HARYANA"', '"JIND"', 2002, 0, 0),
#  ('"HARYANA"', '"KAITHAL"', 2002, 0, 0),
#  ('"HARYANA"', '"KARNAL"', 2002, 0, 0),
#  ('"HARYANA"', '"KURUKSHETRA"', 2002, 0, 0),
#  ('"HARYANA"', '"MAHENDRAGARH"', 2002, 0, 0),
#  ('"HARYANA"', '"PANCHKULA"', 2002, 0, 0),
#  ('"HARYANA"', '"PANIPAT"', 2002, 0, 0),
#  ('"HARYANA"', '"REWARI"', 2002, 0, 0),
#  ('"HARYANA"', '"ROHTAK"', 2002, 0, 0),
#  ('"HARYANA"', '"SIRSA"', 2002, 0, 0),
#  ('"HARYANA"', '"SONIPAT"', 2002, 0, 0),
#  ('"HARYANA"', '"YAMUNANAGAR"', 2002, 0, 0),
#  ('"HARYANA"', '"TOTAL"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"BILASPUR"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"CHAMBA"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"G.R.P."', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"HAMIRPUR"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KANGRA"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KINNAUR"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"KULLU"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"MANDI"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"SHIMLA"', 2002, 1, 0),
#  ('"HIMACHAL PRADESH"', '"SIRMAUR"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"SOLAN"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"UNA"', 2002, 0, 0),
#  ('"HIMACHAL PRADESH"', '"TOTAL"', 2002, 1, 0),
#  ('"JAMMU & KASHMIR"', '"ANANTNAG"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"AWANTIPORA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BARAMULLA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BORDER"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"BUDGAM"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"DODA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"GANDERBAL"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"HANDWARA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"JAMMU"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KARGIL"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KATHUA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KULGAM"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"KUPWARA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"LEH"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"POONCH"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"PULWAMA"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAJOURI"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"RAMBAN"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"REASI"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"SRINAGAR"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"UDHAMPUR"', 2002, 0, 0),
#  ('"JAMMU & KASHMIR"', '"TOTAL"', 2002, 0, 0),
#  ('"JHARKHAND"', '"BOKARO"', 2002, 0, 0),
#  ('"JHARKHAND"', '"CHAIBASA"', 2002, 0, 0),
#  ('"JHARKHAND"', '"DEOGHAR"', 2002, 0, 0),
#  ('"JHARKHAND"', '"DHANBAD RLY."', 2002, 1, 0),
#  ('"JHARKHAND"', '"GODDA"', 2002, 0, 0),
#  ('"JHARKHAND"', '"HAZARIBAGH"', 2002, 0, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR RLY."', 2002, 0, 0),
#  ('"JHARKHAND"', '"KODERMA"', 2002, 1, 0),
#  ('"JHARKHAND"', '"LATEHAR"', 2002, 0, 0),
#  ('"JHARKHAND"', '"LOHARDAGGA"', 2002, 0, 0),
#  ('"JHARKHAND"', '"PAKUR"', 2002, 0, 0),
#  ('"JHARKHAND"', '"SARAIKELA"', 2002, 0, 0),
#  ('"JHARKHAND"', '"SIMDEGA"', 2002, 0, 0),
#  ('"KARNATAKA"', '"BANGALORE COMMR."', 2002, 0, 0),
#  ('"KARNATAKA"', '"BANGALORE RURAL"', 2002, 0, 0),
#  ('"KARNATAKA"', '"BELGAUM"', 2002, 0, 0),
#  ('"KARNATAKA"', '"BELLARY"', 2002, 0, 0),
#  ('"KARNATAKA"', '"BIDAR"', 2002, 1, 0),
#  ('"KARNATAKA"', '"BIJAPUR"', 2002, 0, 0),
#  ('"KARNATAKA"', '"CHAMARAJNAGAR"', 2002, 0, 0),
#  ('"KARNATAKA"', '"DAKSHIN KANNADA"', 2002, 2, 0),
#  ('"KARNATAKA"', '"DAVANAGERE"', 2002, 0, 0),
#  ('"KARNATAKA"', '"DHARWAD COMMR."', 2002, 0, 0),
#  ('"KARNATAKA"', '"DHARWAD RURAL"', 2002, 0, 0),
#  ('"KARNATAKA"', '"GADAG"', 2002, 0, 0),
#  ('"KARNATAKA"', '"HASSAN"', 2002, 0, 0),
#  ('"KARNATAKA"', '"HAVERI"', 2002, 0, 0),
#  ('"KARNATAKA"', '"K.G.F."', 2002, 0, 0),
#  ('"KARNATAKA"', '"KODAGU"', 2002, 0, 0),
#  ('"KARNATAKA"', '"KOLAR"', 2002, 1, 0),
#  ('"KARNATAKA"', '"KOPPAL"', 2002, 0, 0),
#  ('"KARNATAKA"', '"MANDYA"', 2002, 0, 0),
#  ('"KARNATAKA"', '"MYSORE COMMR."', 2002, 0, 0),
#  ('"KARNATAKA"', '"MYSORE RURAL"', 2002, 0, 0),
#  ('"KARNATAKA"', '"RAILWAYS"', 2002, 0, 0),
#  ('"KARNATAKA"', '"SHIMOGA"', 2002, 0, 0),
#  ('"KARNATAKA"', '"TUMKUR"', 2002, 0, 0),
#  ('"KARNATAKA"', '"UDUPI"', 2002, 0, 0),
#  ('"KARNATAKA"', '"UTTAR KANNADA"', 2002, 0, 0),
#  ('"KERALA"', '"ALAPUZHA"', 2002, 0, 0),
#  ('"KERALA"', '"CBCID"', 2002, 0, 0),
#  ('"KERALA"', '"ERNAKULAM"', 2002, 0, 0),
#  ('"KERALA"', '"IDUKKI"', 2002, 3, 0),
#  ('"KERALA"', '"KANNUR"', 2002, 1, 0),
#  ('"KERALA"', '"KASARGOD"', 2002, 2, 0),
#  ('"KERALA"', '"KOLLAM"', 2002, 1, 0),
#  ('"KERALA"', '"KOTTAYAM"', 2002, 0, 0),
#  ('"KERALA"', '"KOZHIKODE"', 2002, 0, 0),
#  ('"KERALA"', '"MALAPPURAM"', 2002, 2, 0),
#  ('"KERALA"', '"PATHANAMTHITTA"', 2002, 1, 0),
#  ('"KERALA"', '"RAILWAYS"', 2002, 0, 0),
#  ('"KERALA"', '"THRISSUR"', 2002, 1, 0),
#  ('"KERALA"', '"TRIVANDRUM"', 2002, 0, 0),
#  ('"KERALA"', '"WAYANADU"', 2002, 5, 0),
#  ('"MADHYA PRADESH"', '"BARWANI"', 2002, 2, 0),
#  ('"MADHYA PRADESH"', '"BHOPAL"', 2002, 6, 0),
#  ('"MADHYA PRADESH"', '"BHOPAL RLY."', 2002, 0, 0),
#  ('"MADHYA PRADESH"', '"CHHATARPUR"', 2002, 1, 0),
#  ('"MADHYA PRADESH"', '"CHHINDWARA"', 2002, 9, 0),
#  ('"MADHYA PRADESH"', '"DATIYA"', 2002, 1, 0),
#  ('"MADHYA PRADESH"', '"DHAR"', 2002, 8, 0),
#  ('"MADHYA PRADESH"', '"GUNA"', 2002, 10, 0),
#  ('"MADHYA PRADESH"', '"HOSHANGABAD"', 2002, 13, 0),
#  ('"MADHYA PRADESH"', '"INDORE RLY."', 2002, 0, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2002, 0, 0),
#  ('"MADHYA PRADESH"', '"KHANDWA"', 2002, 10, 0),
#  ('"MADHYA PRADESH"', '"MANDSAUR"', 2002, 3, 0),
#  ('"MADHYA PRADESH"', '"MORENA"', 2002, 3, 0),
#  ('"MADHYA PRADESH"', '"RAISEN"', 2002, 14, 0),
#  ('"MADHYA PRADESH"', '"SHEOPUR"', 2002, 5, 0),
#  ('"MADHYA PRADESH"', '"SIHORE"', 2002, 5, 0),
#  ('"MADHYA PRADESH"', '"UMARIYA"', 2002, 4, 0),
#  ('"MADHYA PRADESH"', '"VIDISHA"', 2002, 8, 0),
#  ('"MAHARASHTRA"', '"AHMEDNAGAR"', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"AKOLA"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI RURAL"', 2002, 6, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD RURAL"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"BEED"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"BHANDARA"', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"BULDHANA"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"CHANDRAPUR"', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"GADCHIROLI"', 2002, 6, 0),
#  ('"MAHARASHTRA"', '"GONDIA"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"HINGOLI"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"JALGAON"', 2002, 2, 0),
#  ('"MAHARASHTRA"', '"JALNA"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"KOLHAPUR"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"LATUR"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"MUMBAI"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"MUMBAI RLY."', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"NAGPUR COMMR."', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"NAGPUR RLY."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"NAGPUR RURAL"', 2002, 3, 0),
#  ('"MAHARASHTRA"', '"NANDED"', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"NASIK COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"NAVI MUMBAI"', 2002, 1, 0),
#  ('"MAHARASHTRA"', '"OSMANABAD"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"PARBHANI"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"PUNE RURAL"', 2002, 2, 0),
#  ('"MAHARASHTRA"', '"RATNAGIRI"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"SANGLI"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"SATARA"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"SINDHUDURG"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR RURAL"', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"THANE COMMR."', 2002, 0, 0),
#  ('"MAHARASHTRA"', '"WARDHA"', 2002, 5, 0),
#  ('"MAHARASHTRA"', '"WASHIM"', 2002, 1, 0),
#  ('"MANIPUR"', '"BISHNUPUR"', 2002, 0, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2002, 0, 0),
#  ('"MANIPUR"', '"CHURACHANDPUR"', 2002, 0, 0),
#  ('"MANIPUR"', '"IMPHAL(EAST)"', 2002, 0, 0),
#  ('"MANIPUR"', '"IMPHAL(WEST)"', 2002, 0, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2002, 0, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2002, 0, 0),
#  ('"MANIPUR"', '"THOUBAL"', 2002, 0, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2002, 0, 0),
#  ('"MANIPUR"', '"TOTAL"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS EAST"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2002, 1, 0),
#  ('"MEGHALAYA"', '"GARO HILLS WEST"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"JAINTIA HILLS"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS EAST"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS WEST"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"RI-BHOI"', 2002, 0, 0),
#  ('"MEGHALAYA"', '"TOTAL"', 2002, 1, 0),
#  ('"MIZORAM"', '"AIZAWL"', 2002, 0, 0),
#  ('"MIZORAM"', '"CHAMPHAI"', 2002, 0, 0),
#  ('"MIZORAM"', '"LAWNGTLAI"', 2002, 1, 0),
#  ('"MIZORAM"', '"LUNGLEI"', 2002, 1, 0),
#  ('"MIZORAM"', '"MAMIT"', 2002, 0, 0),
#  ('"MIZORAM"', '"SAIHA"', 2002, 0, 0),
#  ('"MIZORAM"', '"SERCHHIP"', 2002, 0, 0),
#  ('"NAGALAND"', '"DIMAPUR"', 2002, 0, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2002, 0, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2002, 0, 0),
#  ('"NAGALAND"', '"MON"', 2002, 0, 0),
#  ('"NAGALAND"', '"PEREN"', 2002, 0, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2002, 0, 0),
#  ('"ODISHA"', '"ANGUL"', 2002, 0, 0),
#  ('"ODISHA"', '"BALASORE"', 2002, 0, 0),
#  ('"ODISHA"', '"BARAGARH"', 2002, 0, 0),
#  ('"ODISHA"', '"BERHAMPUR"', 2002, 0, 0),
#  ('"ODISHA"', '"BHADRAK"', 2002, 0, 0),
#  ('"ODISHA"', '"BOLANGIR"', 2002, 0, 0),
#  ('"ODISHA"', '"BOUDH"', 2002, 0, 0),
#  ('"ODISHA"', '"CUTTACK"', 2002, 0, 0),
#  ('"ODISHA"', '"DEOGARH"', 2002, 0, 0),
#  ('"ODISHA"', '"DHENKANAL"', 2002, 0, 0),
#  ('"ODISHA"', '"GAJAPATI"', 2002, 0, 0),
#  ('"ODISHA"', '"GANJAM"', 2002, 0, 0),
#  ('"ODISHA"', '"JAGATSINGHPUR"', 2002, 0, 0),
#  ('"ODISHA"', '"JAJPUR"', 2002, 0, 0),
#  ('"ODISHA"', '"JHARSUGUDA"', 2002, 0, 0),
#  ('"ODISHA"', '"KALAHANDI"', 2002, 0, 0),
#  ('"ODISHA"', '"KANDHAMAL"', 2002, 3, 0),
#  ('"ODISHA"', '"KENDRAPARA"', 2002, 0, 0),
#  ('"ODISHA"', '"KHURDA"', 2002, 0, 0),
#  ('"ODISHA"', '"NAYAGARH"', 2002, 0, 0),
#  ('"ODISHA"', '"PURI"', 2002, 0, 0),
#  ('"ODISHA"', '"RAYAGADA"', 2002, 0, 0),
#  ('"ODISHA"', '"ROURKELA"', 2002, 0, 0),
#  ('"ODISHA"', '"SAMBALPUR"', 2002, 0, 0),
#  ('"ODISHA"', '"SONEPUR"', 2002, 0, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2002, 0, 0),
#  ('"ODISHA"', '"SRP(ROURKELA)"', 2002, 0, 0),
#  ('"ODISHA"', '"SUNDARGARH"', 2002, 2, 0),
#  ('"PUNJAB"', '"AMRITSAR"', 2002, 0, 0),
#  ('"PUNJAB"', '"BARNALA"', 2002, 0, 0),
#  ...]

# %% [markdown]
# Here is the list of all the districts where Murder against ST happened the lowest

# %% [markdown]
# # 3.7) Write SQL query to find the number of murders in ascending order in district and yearwise.

# %%
result=cursor.execute("SELECT state_UT, DISTRICT, Year,Murder FROM crime_against_st GROUP BY DISTRICT ORDER BY Murder ASC, Year ASC")
result.fetchall()
# Out:
# [('"WEST BENGAL"', '"24 PARGANAS NORTH"', 2001, 0),
#  ('"WEST BENGAL"', '"24 PARGANAS SOUTH"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"ADILABAD"', 2001, 0),
#  ('"UTTAR PRADESH"', '"AGRA"', 2001, 0),
#  ('"GUJARAT"', '"AHMEDABAD COMMR."', 2001, 0),
#  ('"GUJARAT"', '"AHMEDABAD RURAL"', 2001, 0),
#  ('"GUJARAT"', '"AHWA-DANG"', 2001, 0),
#  ('"MIZORAM"', '"AIZAWL"', 2001, 0),
#  ('"RAJASTHAN"', '"AJMER"', 2001, 0),
#  ('"MAHARASHTRA"', '"AKOLA"', 2001, 0),
#  ('"KERALA"', '"ALAPUZHA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"ALLAHABAD"', 2001, 0),
#  ('"UTTARAKHAND"', '"ALMORA"', 2001, 0),
#  ('"RAJASTHAN"', '"ALWAR"', 2001, 0),
#  ('"HARYANA"', '"AMBALA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"AMBEDKAR NAGAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"AMRAVATI RURAL"', 2001, 0),
#  ('"GUJARAT"', '"AMRELI"', 2001, 0),
#  ('"PUNJAB"', '"AMRITSAR"', 2001, 0),
#  ('"GUJARAT"', '"ANAND"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"ANANTAPUR"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"ANANTNAG"', 2001, 0),
#  ('"A & N ISLANDS"', '"ANDAMAN"', 2001, 0),
#  ('"ODISHA"', '"ANGUL"', 2001, 0),
#  ('"TAMIL NADU"', '"ARIYALUR"', 2001, 0),
#  ('"BIHAR"', '"ARWAL"', 2001, 0),
#  ('"WEST BENGAL"', '"ASANSOL"', 2001, 0),
#  ('"UTTAR PRADESH"', '"AURAIYA"', 2001, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"AURANGABAD RURAL"', 2001, 0),
#  ('"BIHAR"', '"AURANGABAD"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"AWANTIPORA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"AZAMGARH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BADAUN"', 2001, 0),
#  ('"BIHAR"', '"BAGAHA"', 2001, 0),
#  ('"KARNATAKA"', '"BAGALKOT"', 2001, 0),
#  ('"UTTARAKHAND"', '"BAGESHWAR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BAGHPAT"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BAHRAICH"', 2001, 0),
#  ('"ODISHA"', '"BALASORE"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BALLIA"', 2001, 0),
#  ('"CHHATTISGARH"', '"BALRAMPUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BANDA"', 2001, 0),
#  ('"KARNATAKA"', '"BANGALORE COMMR."', 2001, 0),
#  ('"KARNATAKA"', '"BANGALORE RURAL"', 2001, 0),
#  ('"BIHAR"', '"BANKA"', 2001, 0),
#  ('"WEST BENGAL"', '"BANKURA"', 2001, 0),
#  ('"RAJASTHAN"', '"BANSWARA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BARABANKI"', 2001, 0),
#  ('"ODISHA"', '"BARAGARH"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"BARAMULLA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BAREILLY"', 2001, 0),
#  ('"RAJASTHAN"', '"BARMER"', 2001, 0),
#  ('"PUNJAB"', '"BARNALA"', 2001, 0),
#  ('"ASSAM"', '"BARPETA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BASTI"', 2001, 0),
#  ('"PUNJAB"', '"BATALA"', 2001, 0),
#  ('"MAHARASHTRA"', '"BEED"', 2001, 0),
#  ('"BIHAR"', '"BEGUSARAI"', 2001, 0),
#  ('"KARNATAKA"', '"BELGAUM"', 2001, 0),
#  ('"KARNATAKA"', '"BELLARY"', 2001, 0),
#  ('"ODISHA"', '"BERHAMPUR"', 2001, 0),
#  ('"BIHAR"', '"BETTIAH"', 2001, 0),
#  ('"MADHYA PRADESH"', '"BETUL"', 2001, 0),
#  ('"BIHAR"', '"BHABHUA"', 2001, 0),
#  ('"ODISHA"', '"BHADRAK"', 2001, 0),
#  ('"BIHAR"', '"BHAGALPUR"', 2001, 0),
#  ('"MAHARASHTRA"', '"BHANDARA"', 2001, 0),
#  ('"RAJASTHAN"', '"BHARATPUR"', 2001, 0),
#  ('"GUJARAT"', '"BHARUCH"', 2001, 0),
#  ('"PUNJAB"', '"BHATINDA"', 2001, 0),
#  ('"GUJARAT"', '"BHAVNAGAR"', 2001, 0),
#  ('"RAJASTHAN"', '"BHILWARA"', 2001, 0),
#  ('"MADHYA PRADESH"', '"BHIND"', 2001, 0),
#  ('"HARYANA"', '"BHIWANI"', 2001, 0),
#  ('"BIHAR"', '"BHOJPUR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"BHOPAL RLY."', 2001, 0),
#  ('"KARNATAKA"', '"BIDAR"', 2001, 0),
#  ('"KARNATAKA"', '"BIJAPUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BIJNOR"', 2001, 0),
#  ('"RAJASTHAN"', '"BIKANER"', 2001, 0),
#  ('"WEST BENGAL"', '"BIRBHUM"', 2001, 0),
#  ('"MANIPUR"', '"BISHNUPUR"', 2001, 0),
#  ('"CHHATTISGARH"', '"BIZAPUR"', 2001, 0),
#  ('"JHARKHAND"', '"BOKARO"', 2001, 0),
#  ('"ASSAM"', '"BONGAIGAON"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"BORDER"', 2001, 0),
#  ('"ODISHA"', '"BOUDH"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"BUDGAM"', 2001, 0),
#  ('"UTTAR PRADESH"', '"BULANDSHAHAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"BULDHANA"', 2001, 0),
#  ('"RAJASTHAN"', '"BUNDI"', 2001, 0),
#  ('"WEST BENGAL"', '"BURDWAN"', 2001, 0),
#  ('"BIHAR"', '"BUXAR"', 2001, 0),
#  ('"ASSAM"', '"C.I.D."', 2001, 0),
#  ('"ASSAM"', '"CACHAR"', 2001, 0),
#  ('"KERALA"', '"CBCID"', 2001, 0),
#  ('"DELHI"', '"CENTRAL"', 2001, 0),
#  ('"JHARKHAND"', '"CHAIBASA"', 2001, 0),
#  ('"KARNATAKA"', '"CHAMARAJNAGAR"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"CHAMBA"', 2001, 0),
#  ('"UTTARAKHAND"', '"CHAMOLI"', 2001, 0),
#  ('"UTTARAKHAND"', '"CHAMPAWAT"', 2001, 0),
#  ('"MIZORAM"', '"CHAMPHAI"', 2001, 0),
#  ('"MANIPUR"', '"CHANDEL"', 2001, 0),
#  ('"CHANDIGARH"', '"CHANDIGARH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"CHANDOLI"', 2001, 0),
#  ('"MAHARASHTRA"', '"CHANDRAPUR"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"CHANGLANG"', 2001, 0),
#  ('"TAMIL NADU"', '"CHENGAI"', 2001, 0),
#  ('"TAMIL NADU"', '"CHENNAI RLY."', 2001, 0),
#  ('"TAMIL NADU"', '"CHENNAI"', 2001, 0),
#  ('"MADHYA PRADESH"', '"CHHATARPUR"', 2001, 0),
#  ('"KARNATAKA"', '"CHICKMAGALUR"', 2001, 0),
#  ('"KARNATAKA"', '"CHITRADURGA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"CHITRAKOOT DHAM"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"CHITTOOR"', 2001, 0),
#  ('"RAJASTHAN"', '"CHITTORGARH"', 2001, 0),
#  ('"MANIPUR"', '"CHURACHANDPUR"', 2001, 0),
#  ('"RAJASTHAN"', '"CHURU"', 2001, 0),
#  ('"TAMIL NADU"', '"COIMBATORE RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"COIMBATORE URBAN"', 2001, 0),
#  ('"WEST BENGAL"', '"COOCHBEHAR"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME JAMMU"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"CRIME SRINAGAR"', 2001, 0),
#  ('"TAMIL NADU"', '"CUDDALORE"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"CUDDAPAH"', 2001, 0),
#  ('"ODISHA"', '"CUTTACK"', 2001, 0),
#  ('"D & N HAVELI"', '"D and N HAVELI"', 2001, 0),
#  ('"GUJARAT"', '"DAHOD"', 2001, 0),
#  ('"WEST BENGAL"', '"DAKSHIN DINAJPUR"', 2001, 0),
#  ('"KARNATAKA"', '"DAKSHIN KANNADA"', 2001, 0),
#  ('"DAMAN & DIU"', '"DAMAN"', 2001, 0),
#  ('"MADHYA PRADESH"', '"DAMOH"', 2001, 0),
#  ('"CHHATTISGARH"', '"DANTEWARA"', 2001, 0),
#  ('"BIHAR"', '"DARBHANGA"', 2001, 0),
#  ('"WEST BENGAL"', '"DARJEELING"', 2001, 0),
#  ('"ASSAM"', '"DARRANG"', 2001, 0),
#  ('"MADHYA PRADESH"', '"DATIYA"', 2001, 0),
#  ('"KARNATAKA"', '"DAVANAGERE"', 2001, 0),
#  ('"UTTARAKHAND"', '"DEHRADUN"', 2001, 0),
#  ('"ODISHA"', '"DEOGARH"', 2001, 0),
#  ('"JHARKHAND"', '"DEOGHAR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"DEORIA"', 2001, 0),
#  ('"MADHYA PRADESH"', '"DEWAS"', 2001, 0),
#  ('"TRIPURA"', '"DHALAI"', 2001, 0),
#  ('"CHHATTISGARH"', '"DHAMTARI"', 2001, 0),
#  ('"JHARKHAND"', '"DHANBAD RLY."', 2001, 0),
#  ('"JHARKHAND"', '"DHANBAD"', 2001, 0),
#  ('"TAMIL NADU"', '"DHARMAPURI"', 2001, 0),
#  ('"KARNATAKA"', '"DHARWAD COMMR."', 2001, 0),
#  ('"KARNATAKA"', '"DHARWAD RURAL"', 2001, 0),
#  ('"ASSAM"', '"DHEMAJI"', 2001, 0),
#  ('"ODISHA"', '"DHENKANAL"', 2001, 0),
#  ('"ASSAM"', '"DHUBRI"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"DIBANG VALLEY"', 2001, 0),
#  ('"ASSAM"', '"DIBRUGARH"', 2001, 0),
#  ('"NAGALAND"', '"DIMAPUR"', 2001, 0),
#  ('"TAMIL NADU"', '"DINDIGUL"', 2001, 0),
#  ('"MADHYA PRADESH"', '"DINDORI"', 2001, 0),
#  ('"DAMAN & DIU"', '"DIU"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"DODA"', 2001, 0),
#  ('"JHARKHAND"', '"DUMKA"', 2001, 0),
#  ('"RAJASTHAN"', '"DUNGARPUR"', 2001, 0),
#  ('"CHHATTISGARH"', '"DURG"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"EAST GODAVARI"', 2001, 0),
#  ('"KERALA"', '"ERNAKULAM"', 2001, 0),
#  ('"TAMIL NADU"', '"ERODE"', 2001, 0),
#  ('"UTTAR PRADESH"', '"ETAH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"ETAWAH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"FAIZABAD"', 2001, 0),
#  ('"HARYANA"', '"FARIDABAD"', 2001, 0),
#  ('"PUNJAB"', '"FARIDKOT"', 2001, 0),
#  ('"HARYANA"', '"FATEHABAD"', 2001, 0),
#  ('"PUNJAB"', '"FATEHGARH SAHIB"', 2001, 0),
#  ('"UTTAR PRADESH"', '"FATEHGARH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"FATEHPUR"', 2001, 0),
#  ('"PUNJAB"', '"FEROZEPUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"FIROZABAD"', 2001, 0),
#  ('"PUNJAB"', '"G.R.P"', 2001, 0),
#  ('"ASSAM"', '"G.R.P."', 2001, 0),
#  ('"DELHI"', '"G.R.P.(RLY)"', 2001, 0),
#  ('"KARNATAKA"', '"GADAG"', 2001, 0),
#  ('"MAHARASHTRA"', '"GADCHIROLI"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"GANDERBAL"', 2001, 0),
#  ('"GUJARAT"', '"GANDHINAGAR"', 2001, 0),
#  ('"RAJASTHAN"', '"GANGANAGAR"', 2001, 0),
#  ('"ODISHA"', '"GANJAM"', 2001, 0),
#  ('"JHARKHAND"', '"GARHWA"', 2001, 0),
#  ('"MEGHALAYA"', '"GARO HILLS EAST"', 2001, 0),
#  ('"MEGHALAYA"', '"GARO HILLS SOUTH"', 2001, 0),
#  ('"MEGHALAYA"', '"GARO HILLS WEST"', 2001, 0),
#  ('"UTTAR PRADESH"', '"GAUTAMBUDH NAGAR"', 2001, 0),
#  ('"BIHAR"', '"GAYA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"GHAZIABAD"', 2001, 0),
#  ('"UTTAR PRADESH"', '"GHAZIPUR"', 2001, 0),
#  ('"JHARKHAND"', '"GIRIDIH"', 2001, 0),
#  ('"ASSAM"', '"GOALPARA"', 2001, 0),
#  ('"JHARKHAND"', '"GODDA"', 2001, 0),
#  ('"ASSAM"', '"GOLAGHAT"', 2001, 0),
#  ('"UTTAR PRADESH"', '"GONDA"', 2001, 0),
#  ('"MAHARASHTRA"', '"GONDIA"', 2001, 0),
#  ('"BIHAR"', '"GOPALGANJ"', 2001, 0),
#  ('"UTTAR PRADESH"', '"GORAKHPUR"', 2001, 0),
#  ('"CHHATTISGARH"', '"GRP RAIPUR"', 2001, 0),
#  ('"HARYANA"', '"GRP"', 2001, 0),
#  ('"KARNATAKA"', '"GULBARGA"', 2001, 0),
#  ('"JHARKHAND"', '"GUMALA"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"GUNTAKAL RLY."', 2001, 0),
#  ('"ANDHRA PRADESH"', '"GUNTUR"', 2001, 0),
#  ('"PUNJAB"', '"GURDASPUR"', 2001, 0),
#  ('"HARYANA"', '"GURGAON"', 2001, 0),
#  ('"ASSAM"', '"GUWAHATI CITY"', 2001, 0),
#  ('"ASSAM"', '"HAILAKANDI"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"HAMIRPUR"', 2001, 0),
#  ('"RAJASTHAN"', '"HANUMANGARH"', 2001, 0),
#  ('"MADHYA PRADESH"', '"HARDA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"HARDOI"', 2001, 0),
#  ('"UTTARAKHAND"', '"HARIDWAR"', 2001, 0),
#  ('"KARNATAKA"', '"HASSAN"', 2001, 0),
#  ('"UTTAR PRADESH"', '"HATHRAS"', 2001, 0),
#  ('"KARNATAKA"', '"HAVERI"', 2001, 0),
#  ('"JHARKHAND"', '"HAZARIBAGH"', 2001, 0),
#  ('"GUJARAT"', '"HIMATNAGAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"HINGOLI"', 2001, 0),
#  ('"HARYANA"', '"HISAR"', 2001, 0),
#  ('"WEST BENGAL"', '"HOOGHLY"', 2001, 0),
#  ('"PUNJAB"', '"HOSHIARPUR"', 2001, 0),
#  ('"WEST BENGAL"', '"HOWRAH CITY"', 2001, 0),
#  ('"WEST BENGAL"', '"HOWRAH G.R.P."', 2001, 0),
#  ('"WEST BENGAL"', '"HOWRAH"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"HYDERABAD CITY"', 2001, 0),
#  ('"DELHI"', '"I.G.I.AIRPORT"', 2001, 0),
#  ('"KERALA"', '"IDUKKI"', 2001, 0),
#  ('"MANIPUR"', '"IMPHAL(EAST)"', 2001, 0),
#  ('"MANIPUR"', '"IMPHAL(WEST)"', 2001, 0),
#  ('"MADHYA PRADESH"', '"INDORE RLY."', 2001, 0),
#  ('"MADHYA PRADESH"', '"INDORE"', 2001, 0),
#  ('"UTTAR PRADESH"', '"J.P.NAGAR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"JABALPUR RLY."', 2001, 0),
#  ('"ODISHA"', '"JAGATSINGHPUR"', 2001, 0),
#  ('"PUNJAB"', '"JAGRAON"', 2001, 0),
#  ('"MEGHALAYA"', '"JAINTIA HILLS"', 2001, 0),
#  ('"RAJASTHAN"', '"JAISALMER"', 2001, 0),
#  ('"ODISHA"', '"JAJPUR"', 2001, 0),
#  ('"PUNJAB"', '"JALANDHAR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"JALAUN"', 2001, 0),
#  ('"MAHARASHTRA"', '"JALGAON"', 2001, 0),
#  ('"MAHARASHTRA"', '"JALNA"', 2001, 0),
#  ('"RAJASTHAN"', '"JALORE"', 2001, 0),
#  ('"WEST BENGAL"', '"JALPAIGURI"', 2001, 0),
#  ('"BIHAR"', '"JAMALPUR RLY."', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"JAMMU"', 2001, 0),
#  ('"GUJARAT"', '"JAMNAGAR"', 2001, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR RLY."', 2001, 0),
#  ('"JHARKHAND"', '"JAMSHEDPUR"', 2001, 0),
#  ('"JHARKHAND"', '"JAMTARA"', 2001, 0),
#  ('"BIHAR"', '"JAMUI"', 2001, 0),
#  ('"CHHATTISGARH"', '"JASHPUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"JAUNPUR"', 2001, 0),
#  ('"BIHAR"', '"JEHANABAD"', 2001, 0),
#  ('"MADHYA PRADESH"', '"JHABUA"', 2001, 0),
#  ('"HARYANA"', '"JHAJJAR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"JHANSI"', 2001, 0),
#  ('"ODISHA"', '"JHARSUGUDA"', 2001, 0),
#  ('"HARYANA"', '"JIND"', 2001, 0),
#  ('"RAJASTHAN"', '"JODHPUR"', 2001, 0),
#  ('"ASSAM"', '"JORHAT"', 2001, 0),
#  ('"GUJARAT"', '"JUNAGADH"', 2001, 0),
#  ('"KARNATAKA"', '"K.G.F."', 2001, 0),
#  ('"HARYANA"', '"KAITHAL"', 2001, 0),
#  ('"ODISHA"', '"KALAHANDI"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG EAST"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"KAMENG WEST"', 2001, 0),
#  ('"ASSAM"', '"KAMRUP"', 2001, 0),
#  ('"TAMIL NADU"', '"KANCHIPURAM"', 2001, 0),
#  ('"ODISHA"', '"KANDHAMAL"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"KANGRA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KANNAUJ"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KANPUR DEHAT"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KANPUR NAGAR"', 2001, 0),
#  ('"TAMIL NADU"', '"KANYAKUMARI"', 2001, 0),
#  ('"PUNJAB"', '"KAPURTHALA"', 2001, 0),
#  ('"RAJASTHAN"', '"KARAULI"', 2001, 0),
#  ('"ASSAM"', '"KARBI ANGLONG"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"KARGIL"', 2001, 0),
#  ('"ASSAM"', '"KARIMGANJ"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"KARIMNAGAR"', 2001, 0),
#  ('"HARYANA"', '"KARNAL"', 2001, 0),
#  ('"TAMIL NADU"', '"KARUR"', 2001, 0),
#  ('"KERALA"', '"KASARGOD"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"KATHUA"', 2001, 0),
#  ('"BIHAR"', '"KATIHAR RLY."', 2001, 0),
#  ('"BIHAR"', '"KATIHAR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"KATNI"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KAUSHAMBI"', 2001, 0),
#  ('"ODISHA"', '"KENDRAPARA"', 2001, 0),
#  ('"ODISHA"', '"KEONJHAR"', 2001, 0),
#  ('"BIHAR"', '"KHAGARIA"', 2001, 0),
#  ('"PUNJAB"', '"KHANNA"', 2001, 0),
#  ('"MADHYA PRADESH"', '"KHARGON"', 2001, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS EAST"', 2001, 0),
#  ('"MEGHALAYA"', '"KHASI HILLS WEST"', 2001, 0),
#  ('"GUJARAT"', '"KHEDA NORTH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KHIRI"', 2001, 0),
#  ('"ODISHA"', '"KHURDA"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"KINNAUR"', 2001, 0),
#  ('"NAGALAND"', '"KIPHIRE"', 2001, 0),
#  ('"BIHAR"', '"KISHANGANJ"', 2001, 0),
#  ('"JHARKHAND"', '"KODERMA"', 2001, 0),
#  ('"ASSAM"', '"KOKRAJHAR"', 2001, 0),
#  ('"KARNATAKA"', '"KOLAR"', 2001, 0),
#  ('"MIZORAM"', '"KOLASIB"', 2001, 0),
#  ('"MAHARASHTRA"', '"KOLHAPUR"', 2001, 0),
#  ('"WEST BENGAL"', '"KOLKATA"', 2001, 0),
#  ('"KERALA"', '"KOLLAM"', 2001, 0),
#  ('"KARNATAKA"', '"KOPPAL"', 2001, 0),
#  ('"ODISHA"', '"KORAPUT"', 2001, 0),
#  ('"CHHATTISGARH"', '"KORIYA"', 2001, 0),
#  ('"KERALA"', '"KOTTAYAM"', 2001, 0),
#  ('"KERALA"', '"KOZHIKODE"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"KRISHNA"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"KULGAM"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"KULLU"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"KUPWARA"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"KURNOOL"', 2001, 0),
#  ('"HARYANA"', '"KURUKSHETRA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"KUSHI NAGAR"', 2001, 0),
#  ('"GUJARAT"', '"KUTCH"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"LAHAUL-SPITI"', 2001, 0),
#  ('"ASSAM"', '"LAKHIMPUR"', 2001, 0),
#  ('"BIHAR"', '"LAKHISARAI"', 2001, 0),
#  ('"LAKSHADWEEP"', '"LAKSHADWEEP"', 2001, 0),
#  ('"UTTAR PRADESH"', '"LALITPUR"', 2001, 0),
#  ('"JHARKHAND"', '"LATEHAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"LATUR"', 2001, 0),
#  ('"MIZORAM"', '"LAWNGTLAI"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"LEH"', 2001, 0),
#  ('"JHARKHAND"', '"LOHARDAGGA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"LUCKNOW"', 2001, 0),
#  ('"PUNJAB"', '"LUDHIANA"', 2001, 0),
#  ('"MIZORAM"', '"LUNGLEI"', 2001, 0),
#  ('"BIHAR"', '"MADHEPURA"', 2001, 0),
#  ('"BIHAR"', '"MADHUBANI"', 2001, 0),
#  ('"TAMIL NADU"', '"MADURAI RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"MADURAI URBAN"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MAHARAJGANJ"', 2001, 0),
#  ('"CHHATTISGARH"', '"MAHASAMUND"', 2001, 0),
#  ('"HARYANA"', '"MAHENDERGARH"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MAHOBA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MAINPURI"', 2001, 0),
#  ('"PUNJAB"', '"MAJITHA"', 2001, 0),
#  ('"KERALA"', '"MALAPPURAM"', 2001, 0),
#  ('"WEST BENGAL"', '"MALDA"', 2001, 0),
#  ('"ODISHA"', '"MALKANGIR"', 2001, 0),
#  ('"MIZORAM"', '"MAMIT"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"MANDI"', 2001, 0),
#  ('"MADHYA PRADESH"', '"MANDSAUR"', 2001, 0),
#  ('"KARNATAKA"', '"MANDYA"', 2001, 0),
#  ('"PUNJAB"', '"MANSA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MATHURA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MAU"', 2001, 0),
#  ('"ODISHA"', '"MAYURBHANJ"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"MEDAK"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MEERUT"', 2001, 0),
#  ('"GUJARAT"', '"MEHSANA"', 2001, 0),
#  ('"WEST BENGAL"', '"MIDNAPUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MIRZAPUR"', 2001, 0),
#  ('"PUNJAB"', '"MOGA"', 2001, 0),
#  ('"NAGALAND"', '"MOKOKCHUNG"', 2001, 0),
#  ('"MADHYA PRADESH"', '"MORENA"', 2001, 0),
#  ('"ASSAM"', '"MORIGAON"', 2001, 0),
#  ('"BIHAR"', '"MOTIHARI"', 2001, 0),
#  ('"PUNJAB"', '"MUKTSAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"MUMBAI RLY."', 2001, 0),
#  ('"MAHARASHTRA"', '"MUMBAI"', 2001, 0),
#  ('"BIHAR"', '"MUNGER"', 2001, 0),
#  ('"WEST BENGAL"', '"MURSHIDABAD"', 2001, 0),
#  ('"UTTAR PRADESH"', '"MUZAFFARNAGAR"', 2001, 0),
#  ('"BIHAR"', '"MUZAFFARPUR RLY."', 2001, 0),
#  ('"BIHAR"', '"MUZAFFARPUR"', 2001, 0),
#  ('"KARNATAKA"', '"MYSORE COMMR."', 2001, 0),
#  ('"KARNATAKA"', '"MYSORE RURAL"', 2001, 0),
#  ('"ASSAM"', '"N.C. HILLS"', 2001, 0),
#  ('"WEST BENGAL"', '"NADIA"', 2001, 0),
#  ('"ASSAM"', '"NAGAON"', 2001, 0),
#  ('"TAMIL NADU"', '"NAGAPATTINAM"', 2001, 0),
#  ('"RAJASTHAN"', '"NAGAUR"', 2001, 0),
#  ('"MAHARASHTRA"', '"NAGPUR COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"NAGPUR RURAL"', 2001, 0),
#  ('"UTTARAKHAND"', '"NAINITAL"', 2001, 0),
#  ('"BIHAR"', '"NALANDA"', 2001, 0),
#  ('"ASSAM"', '"NALBARI"', 2001, 0),
#  ('"TAMIL NADU"', '"NAMAKKAL"', 2001, 0),
#  ('"MAHARASHTRA"', '"NANDED"', 2001, 0),
#  ('"MAHARASHTRA"', '"NANDURBAR"', 2001, 0),
#  ('"GUJARAT"', '"NARMADA"', 2001, 0),
#  ('"MADHYA PRADESH"', '"NARSINGHPUR"', 2001, 0),
#  ('"MAHARASHTRA"', '"NASIK COMMR."', 2001, 0),
#  ('"BIHAR"', '"NAUGACHIA"', 2001, 0),
#  ('"MAHARASHTRA"', '"NAVI MUMBAI"', 2001, 0),
#  ('"GUJARAT"', '"NAVSARI"', 2001, 0),
#  ('"BIHAR"', '"NAWADAH"', 2001, 0),
#  ('"PUNJAB"', '"NAWAN SHAHR"', 2001, 0),
#  ('"ODISHA"', '"NAYAGARH"', 2001, 0),
#  ('"MADHYA PRADESH"', '"NEEMUCH"', 2001, 0),
#  ('"DELHI"', '"NEW DELHI"', 2001, 0),
#  ('"A & N ISLANDS"', '"NICOBAR"', 2001, 0),
#  ('"TAMIL NADU"', '"NILGIRIS"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"NIZAMABAD"', 2001, 0),
#  ('"DELHI"', '"NORTH EAST"', 2001, 0),
#  ('"GOA"', '"NORTH GOA"', 2001, 0),
#  ('"DELHI"', '"NORTH WEST"', 2001, 0),
#  ('"SIKKIM"', '"NORTH"', 2001, 0),
#  ('"ODISHA"', '"NOWRANGPUR"', 2001, 0),
#  ('"ODISHA"', '"NUAPADA"', 2001, 0),
#  ('"MAHARASHTRA"', '"OSMANABAD"', 2001, 0),
#  ('"JHARKHAND"', '"PAKUR"', 2001, 0),
#  ('"JHARKHAND"', '"PALAMU"', 2001, 0),
#  ('"HARYANA"', '"PANCHKULA"', 2001, 0),
#  ('"HARYANA"', '"PANIPAT"', 2001, 0),
#  ('"MAHARASHTRA"', '"PARBHANI"', 2001, 0),
#  ('"GUJARAT"', '"PATAN"', 2001, 0),
#  ('"KERALA"', '"PATHANAMTHITTA"', 2001, 0),
#  ('"PUNJAB"', '"PATIALA"', 2001, 0),
#  ('"BIHAR"', '"PATNA RLY."', 2001, 0),
#  ('"BIHAR"', '"PATNA"', 2001, 0),
#  ('"UTTARAKHAND"', '"PAURI GARHWAL"', 2001, 0),
#  ('"TAMIL NADU"', '"PERAMBALUR"', 2001, 0),
#  ('"NAGALAND"', '"PEREN"', 2001, 0),
#  ('"UTTAR PRADESH"', '"PILIBHIT"', 2001, 0),
#  ('"UTTARAKHAND"', '"PITHORAGARH"', 2001, 0),
#  ('"PUDUCHERRY"', '"PONDICHERRY"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"POONCH"', 2001, 0),
#  ('"GUJARAT"', '"PORBANDAR"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"PRAKASHAM"', 2001, 0),
#  ('"UTTAR PRADESH"', '"PRATAPGARH"', 2001, 0),
#  ('"TAMIL NADU"', '"PUDUKOTTAI"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"PULWAMA"', 2001, 0),
#  ('"MAHARASHTRA"', '"PUNE COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"PUNE RLY."', 2001, 0),
#  ('"ODISHA"', '"PURI"', 2001, 0),
#  ('"BIHAR"', '"PURNEA"', 2001, 0),
#  ('"WEST BENGAL"', '"PURULIA"', 2001, 0),
#  ('"ASSAM"', '"R.P.O."', 2001, 0),
#  ('"UTTAR PRADESH"', '"RAIBAREILLY"', 2001, 0),
#  ('"KARNATAKA"', '"RAICHUR"', 2001, 0),
#  ('"MAHARASHTRA"', '"RAIGAD"', 2001, 0),
#  ('"CHHATTISGARH"', '"RAIGARH"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS"', 2001, 0),
#  ('"CHHATTISGARH"', '"RAIPUR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"RAISEN"', 2001, 0),
#  ('"GUJARAT"', '"RAJKOT COMMR."', 2001, 0),
#  ('"GUJARAT"', '"RAJKOT RURAL"', 2001, 0),
#  ('"CHHATTISGARH"', '"RAJNANDGAON"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"RAJOURI"', 2001, 0),
#  ('"RAJASTHAN"', '"RAJSAMAND"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"RAMBAN"', 2001, 0),
#  ('"TAMIL NADU"', '"RAMNATHAPURAM"', 2001, 0),
#  ('"UTTAR PRADESH"', '"RAMPUR"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"RANGA REDDY"', 2001, 0),
#  ('"MAHARASHTRA"', '"RATNAGIRI"', 2001, 0),
#  ('"ODISHA"', '"RAYAGADA"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"REASI"', 2001, 0),
#  ('"MADHYA PRADESH"', '"REWA"', 2001, 0),
#  ('"HARYANA"', '"REWARI"', 2001, 0),
#  ('"MEGHALAYA"', '"RI-BHOI"', 2001, 0),
#  ('"HARYANA"', '"ROHTAK"', 2001, 0),
#  ('"BIHAR"', '"ROHTAS"', 2001, 0),
#  ('"PUNJAB"', '"ROPAR"', 2001, 0),
#  ('"ODISHA"', '"ROURKELA"', 2001, 0),
#  ('"UTTARAKHAND"', '"RUDRA PRAYAG"', 2001, 0),
#  ('"DELHI"', '"S.T.F."', 2001, 0),
#  ('"UTTAR PRADESH"', '"SAHARANPUR"', 2001, 0),
#  ('"BIHAR"', '"SAHARSA"', 2001, 0),
#  ('"MIZORAM"', '"SAIHA"', 2001, 0),
#  ('"TAMIL NADU"', '"SALEM RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"SALEM URBAN"', 2001, 0),
#  ('"BIHAR"', '"SAMASTIPUR"', 2001, 0),
#  ('"ODISHA"', '"SAMBALPUR"', 2001, 0),
#  ('"MAHARASHTRA"', '"SANGLI"', 2001, 0),
#  ('"PUNJAB"', '"SANGRUR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SANT KABIRNAGAR"', 2001, 0),
#  ('"JHARKHAND"', '"SARAIKELA"', 2001, 0),
#  ('"BIHAR"', '"SARAN"', 2001, 0),
#  ('"MAHARASHTRA"', '"SATARA"', 2001, 0),
#  ('"MADHYA PRADESH"', '"SATNA"', 2001, 0),
#  ('"RAJASTHAN"', '"SAWAI MADHOPUR"', 2001, 0),
#  ('"WEST BENGAL"', '"SEALDAH G.R.P."', 2001, 0),
#  ('"ANDHRA PRADESH"', '"SECUNDERABAD RLY."', 2001, 0),
#  ('"MANIPUR"', '"SENAPATI"', 2001, 0),
#  ('"MADHYA PRADESH"', '"SEONI"', 2001, 0),
#  ('"MIZORAM"', '"SERCHHIP"', 2001, 0),
#  ('"MADHYA PRADESH"', '"SHAHDOL"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SHAHJAHANPUR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"SHAJAPUR"', 2001, 0),
#  ('"BIHAR"', '"SHEIKHPURA"', 2001, 0),
#  ('"BIHAR"', '"SHEOHAR"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"SHIMLA"', 2001, 0),
#  ('"KARNATAKA"', '"SHIMOGA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SHRAWASTI"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG UPPER"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"SIANG WEST"', 2001, 0),
#  ('"ASSAM"', '"SIBSAGAR"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SIDHARTHNAGAR"', 2001, 0),
#  ('"MADHYA PRADESH"', '"SIDHI"', 2001, 0),
#  ('"RAJASTHAN"', '"SIKAR"', 2001, 0),
#  ('"WEST BENGAL"', '"SILIGURI G.R.P."', 2001, 0),
#  ('"JHARKHAND"', '"SIMDEGA"', 2001, 0),
#  ('"MAHARASHTRA"', '"SINDHUDURG"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"SIRMAUR"', 2001, 0),
#  ('"HARYANA"', '"SIRSA"', 2001, 0),
#  ('"BIHAR"', '"SITAMARHI"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SITAPUR"', 2001, 0),
#  ('"TAMIL NADU"', '"SIVAGANGAI"', 2001, 0),
#  ('"BIHAR"', '"SIWAN"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"SOLAN"', 2001, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"SOLAPUR RURAL"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SONBHADRA"', 2001, 0),
#  ('"ODISHA"', '"SONEPUR"', 2001, 0),
#  ('"HARYANA"', '"SONIPAT"', 2001, 0),
#  ('"ASSAM"', '"SONITPUR"', 2001, 0),
#  ('"GOA"', '"SOUTH GOA"', 2001, 0),
#  ('"DELHI"', '"SOUTH WEST"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"SRIKAKULAM"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"SRINAGAR"', 2001, 0),
#  ('"ODISHA"', '"SRP(CUTTACK)"', 2001, 0),
#  ('"ODISHA"', '"SRP(ROURKELA)"', 2001, 0),
#  ('"UTTAR PRADESH"', '"ST.RAVIDASNAGAR"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI LOWER"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"SUBANSIRI UPPER"', 2001, 0),
#  ('"UTTAR PRADESH"', '"SULTANPUR"', 2001, 0),
#  ('"BIHAR"', '"SUPAUL"', 2001, 0),
#  ('"GUJARAT"', '"SURAT COMMR."', 2001, 0),
#  ('"GUJARAT"', '"SURENDRANAGAR"', 2001, 0),
#  ('"MANIPUR"', '"TAMENGLONG"', 2001, 0),
#  ('"PUNJAB"', '"TARN TARAN"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"TAWANG"', 2001, 0),
#  ('"UTTARAKHAND"', '"TEHRI GARHWAL"', 2001, 0),
#  ('"MAHARASHTRA"', '"THANE COMMR."', 2001, 0),
#  ('"MAHARASHTRA"', '"THANE RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"THANJAVUR"', 2001, 0),
#  ('"TAMIL NADU"', '"THENI"', 2001, 0),
#  ('"TAMIL NADU"', '"THIRUNELVELI RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"THIRUNELVELI URBAN"', 2001, 0),
#  ('"TAMIL NADU"', '"THIRUVALLUR"', 2001, 0),
#  ('"TAMIL NADU"', '"THIRUVANNAMALAI"', 2001, 0),
#  ('"TAMIL NADU"', '"THIRUVARUR"', 2001, 0),
#  ('"TAMIL NADU"', '"THOOTHUGUDI"', 2001, 0),
#  ('"MANIPUR"', '"THOUBAL"', 2001, 0),
#  ('"ASSAM"', '"TINSUKIA"', 2001, 0),
#  ('"ARUNACHAL PRADESH"', '"TIRAP"', 2001, 0),
#  ('"RAJASTHAN"', '"TONK"', 2001, 0),
#  ('"TAMIL NADU"', '"TRICHY RLY."', 2001, 0),
#  ('"TAMIL NADU"', '"TRICHY RURAL"', 2001, 0),
#  ('"TAMIL NADU"', '"TRICHY URBAN"', 2001, 0),
#  ('"KERALA"', '"TRIVANDRUM"', 2001, 0),
#  ('"NAGALAND"', '"TUENSANG"', 2001, 0),
#  ('"KARNATAKA"', '"TUMKUR"', 2001, 0),
#  ('"JAMMU & KASHMIR"', '"UDHAMPUR"', 2001, 0),
#  ('"KARNATAKA"', '"UDUPI"', 2001, 0),
#  ('"MADHYA PRADESH"', '"UJJAIN"', 2001, 0),
#  ('"MANIPUR"', '"UKHRUL"', 2001, 0),
#  ('"MADHYA PRADESH"', '"UMARIYA"', 2001, 0),
#  ('"HIMACHAL PRADESH"', '"UNA"', 2001, 0),
#  ('"UTTAR PRADESH"', '"UNNAO"', 2001, 0),
#  ('"WEST BENGAL"', '"UTTAR DINAJPUR"', 2001, 0),
#  ('"KARNATAKA"', '"UTTAR KANNADA"', 2001, 0),
#  ('"UTTARAKHAND"', '"UTTARKASHI"', 2001, 0),
#  ('"BIHAR"', '"VAISHALI"', 2001, 0),
#  ('"GUJARAT"', '"VALSAD"', 2001, 0),
#  ('"UTTAR PRADESH"', '"VARANASI"', 2001, 0),
#  ('"TAMIL NADU"', '"VELLORE"', 2001, 0),
#  ('"MADHYA PRADESH"', '"VIDISHA"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA RLY."', 2001, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA"', 2001, 0),
#  ('"TAMIL NADU"', '"VILLUPURAM"', 2001, 0),
#  ('"TAMIL NADU"', '"VIRUDHUNAGAR"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHA RURAL"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"VISAKHAPATNAM"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"VIZIANAGARAM"', 2001, 0),
#  ('"GUJARAT"', '"W.RLY"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"WARANGAL"', 2001, 0),
#  ('"MAHARASHTRA"', '"WARDHA"', 2001, 0),
#  ('"MAHARASHTRA"', '"WASHIM"', 2001, 0),
#  ('"ANDHRA PRADESH"', '"WEST GODAVARI"', 2001, 0),
#  ('"SIKKIM"', '"WEST"', 2001, 0),
#  ('"HARYANA"', '"YAMUNANAGAR"', 2001, 0),
#  ('"MAHARASHTRA"', '"YAVATMAL"', 2001, 0),
#  ('"DELHI"', '"DRP"', 2002, 0),
#  ('"JAMMU & KASHMIR"', '"HANDWARA"', 2002, 0),
#  ('"HARYANA"', '"HISSAR"', 2002, 0),
#  ('"DELHI"', '"IGI AIRPORT"', 2002, 0),
#  ('"CHHATTISGARH"', '"KABIRDHAM"', 2002, 0),
#  ('"WEST BENGAL"', '"KHARAGPUR G.R.P."', 2002, 0),
#  ('"HARYANA"', '"MAHENDRAGARH"', 2002, 0),
#  ('"DELHI"', '"NORTH-EAST"', 2002, 0),
#  ('"DELHI"', '"NORTH-WEST"', 2002, 0),
#  ('"WEST BENGAL"', '"PASCHIM MIDNAPUR"', 2002, 0),
#  ('"WEST BENGAL"', '"PURAB MIDNAPUR"', 2002, 0),
#  ('"DELHI"', '"SOUTH-WEST"', 2002, 0),
#  ('"DELHI"', '"SPL CELL"', 2002, 0),
#  ('"DELHI"', '"STF"', 2002, 0),
#  ('"MADHYA PRADESH"', '"ANUPPUR"', 2003, 0),
#  ('"MADHYA PRADESH"', '"ASHOK NAGAR"', 2003, 0),
#  ('"MADHYA PRADESH"', '"BURHANPUR"', 2003, 0),
#  ('"ANDHRA PRADESH"', '"CYBERABAD"', 2003, 0),
#  ('"KERALA"', '"ERNAKULAM COMMR."', 2003, 0),
#  ('"KERALA"', '"ERNAKULAM RURAL"', 2003, 0),
#  ('"DELHI"', '"GRP(RLY)"', 2003, 0),
#  ('"ARUNACHAL PRADESH"', '"K/KUMEY"', 2003, 0),
#  ('"KERALA"', '"KOZHIKODE COMMR."', 2003, 0),
#  ('"KERALA"', '"KOZHIKODE RURAL"', 2003, 0),
#  ('"CHHATTISGARH"', '"NARAYANPUR"', 2003, 0),
#  ('"KERALA"', '"TRIVANDRUM COMMR."', 2003, 0),
#  ('"KERALA"', '"TRIVANDRUM RURAL"', 2003, 0),
#  ('"ARUNACHAL PRADESH"', '"UPPER DIBANG VALLEY"', 2003, 0),
#  ('"PUNJAB"', '"FEROZPUR"', 2004, 0),
#  ('"TAMIL NADU"', '"KRISHNAGIRI"', 2004, 0),
#  ('"ASSAM"', '"BASKA"', 2005, 0),
#  ('"ASSAM"', '"CHIRANG"', 2005, 0),
#  ('"HARYANA"', '"MEWAT"', 2005, 0),
#  ('"TAMIL NADU"', '"VILUPPURAM"', 2005, 0),
#  ('"JAMMU & KASHMIR"', '"BORDER DISTRICT"', 2006, 0),
#  ('"MANIPUR"', '"IMPHAL EAST"', 2006, 0),
#  ('"MANIPUR"', '"IMPHAL WEST"', 2006, 0),
#  ('"RAJASTHAN"', '"JAIPUR NORTH"', 2006, 0),
#  ('"RAJASTHAN"', '"JODHPUR CITY"', 2006, 0),
#  ('"PUDUCHERRY"', '"KARAIKAL"', 2006, 0),
#  ('"MAHARASHTRA"', '"MUMBAI COMMR."', 2006, 0),
#  ('"HARYANA"', '"PALWAL"', 2006, 0),
#  ('"PUNJAB"', '"SAS NGR"', 2006, 0),
#  ('"ANDHRA PRADESH"', '"VIJAYAWADA CITY"', 2006, 0),
#  ('"A & N ISLANDS"', '"A and N ISLANDS"', 2007, 0),
#  ('"PUNJAB"', '"AMRITSAR RURAL"', 2007, 0),
#  ('"NAGALAND"', '"LONGLENG"', 2007, 0),
#  ('"DELHI"', '"OUTER"', 2007, 0),
#  ('"JHARKHAND"', '"RAMGARH"', 2007, 0),
#  ('"MADHYA PRADESH"', '"ALIRAJPUR"', 2008, 0),
#  ('"JAMMU & KASHMIR"', '"BANDIPORA"', 2008, 0),
#  ('"DELHI"', '"CAW"', 2008, 0),
#  ('"KARNATAKA"', '"CBPURA"', 2008, 0),
#  ('"TAMIL NADU"', '"CHENNAISUBURBAN"', 2008, 0),
#  ('"MANIPUR"', '"CID"', 2008, 0),
#  ('"DELHI"', '"CRIME BRANCH"', 2008, 0),
#  ('"CHHATTISGARH"', '"DANTEWADA"', 2008, 0),
#  ('"ODISHA"', '"DCP BBSR"', 2008, 0),
#  ('"ODISHA"', '"DCP CTC"', 2008, 0),
#  ('"DELHI"', '"EOW"', 2008, 0),
#  ('"UTTAR PRADESH"', '"KANSHIRAM NAGAR"', 2008, 0),
#  ('"JAMMU & KASHMIR"', '"KISHTWAR"', 2008, 0),
#  ('"PUNJAB"', '"LUDHIANA RURAL"', 2008, 0),
#  ('"PUDUCHERRY"', '"PUDUCHERRY"', 2008, 0),
#  ('"KARNATAKA"', '"RAMANAGAR"', 2008, 0),
#  ('"JAMMU & KASHMIR"', '"SAMBA"', 2008, 0),
#  ('"PUNJAB"', '"SBS NAGAR"', 2008, 0),
#  ('"JAMMU & KASHMIR"', '"SHOPIAN"', 2008, 0),
#  ('"MADHYA PRADESH"', '"SINGRAULI"', 2008, 0),
#  ('"DELHI"', '"SOUTH-EAST"', 2008, 0),
#  ('"GUJARAT"', '"TAPI"', 2008, 0),
#  ('"ARUNACHAL PRADESH"', '"ANJAW"', 2009, 0),
#  ('"HIMACHAL PRADESH"', '"BADDIPOLICEDIST"', 2009, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KMR"', 2009, 0),
#  ('"TAMIL NADU"', '"TIRUPPUR"', 2009, 0),
#  ('"JAMMU & KASHMIR"', '"C.B.KASHMIR"', 2010, 0),
#  ('"GUJARAT"', '"CID CRIME"', 2010, 0),
#  ('"PUNJAB"', '"CP AMRITSAR"', 2010, 0),
#  ('"PUNJAB"', '"CP JALANDHAR"', 2010, 0),
#  ('"PUNJAB"', '"CP LUDHIANA"', 2010, 0),
#  ('"UTTAR PRADESH"', '"CSM NAGAR"', 2010, 0),
#  ('"RAJASTHAN"', '"G.R.P. AJMER"', 2010, 0),
#  ('"RAJASTHAN"', '"G.R.P. JODHPUR"', 2010, 0),
#  ('"ANDHRA PRADESH"', '"GUNTUR URBAN"', 2010, 0),
#  ('"PUNJAB"', '"JALANDHAR RURAL"', 2010, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYSKMR"', 2010, 0),
#  ('"ANDHRA PRADESH"', '"RAJAHMUNDRY"', 2010, 0),
#  ('"UTTAR PRADESH"', '"RAMABAI NAGAR"', 2010, 0),
#  ('"ARUNACHAL PRADESH"', '"RURAL"', 2010, 0),
#  ('"JAMMU & KASHMIR"', '"SOPORE"', 2010, 0),
#  ('"ANDHRA PRADESH"', '"TIRUPATHI URBAN"', 2010, 0),
#  ('"ANDHRA PRADESH"', '"WARANGAL URBAN"', 2010, 0),
#  ('"KARNATAKA"', '"YADGIRI"', 2010, 0),
#  ('"UTTAR PRADESH"', '"BHIM NAGAR"', 2011, 0),
#  ('"PUNJAB"', '"FAZILKA"', 2011, 0),
#  ('"RAJASTHAN"', '"G.R.P.AJMER"', 2011, 0),
#  ('"RAJASTHAN"', '"G.R.P.JODHPUR"', 2011, 0),
#  ('"RAJASTHAN"', '"JAIPUR WEST"', 2011, 0),
#  ('"KERALA"', '"KOLLAM COMMR."', 2011, 0),
#  ('"KERALA"', '"KOLLAM RURAL"', 2011, 0),
#  ('"GUJARAT"', '"KUTCH (EAST(G))"', 2011, 0),
#  ('"GUJARAT"', '"KUTCH (WEST-BHUJ)"', 2011, 0),
#  ('"KARNATAKA"', '"MANGALORE CITY"', 2011, 0),
#  ('"UTTAR PRADESH"', '"PANCHSHIL NAGAR"', 2011, 0),
#  ('"PUNJAB"', '"PATHANKOT"', 2011, 0),
#  ('"UTTAR PRADESH"', '"PRABUDDH NAGAR"', 2011, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS JAMMU"', 2011, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KASHMIR"', 2011, 0),
#  ('"KERALA"', '"THRISSUR COMMR."', 2011, 0),
#  ('"KERALA"', '"THRISSUR RURAL"', 2011, 0),
#  ('"GUJARAT"', '"W.RLY AHMEDABAD"', 2011, 0),
#  ('"GUJARAT"', '"W.RLY VADODARA"', 2011, 0),
#  ('"HARYANA"', '"AMBALA RURAL"', 2012, 0),
#  ('"HARYANA"', '"AMBALA URBAN"', 2012, 0),
#  ('"ASSAM"', '"BAKSA"', 2012, 0),
#  ('"CHHATTISGARH"', '"BALOD"', 2012, 0),
#  ('"CHHATTISGARH"', '"BALODA BAZAR"', 2012, 0),
#  ('"WEST BENGAL"', '"BDN CP"', 2012, 0),
#  ('"CHHATTISGARH"', '"BEMETARA"', 2012, 0),
#  ('"ASSAM"', '"BIEO"', 2012, 0),
#  ('"WEST BENGAL"', '"BKP CP"', 2012, 0),
#  ('"A & N ISLANDS"', '"CAR"', 2012, 0),
#  ('"TRIPURA"', '"GOMATI"', 2012, 0),
#  ('"ASSAM"', '"HAMREN"', 2012, 0),
#  ('"WEST BENGAL"', '"JHARGRAM"', 2012, 0),
#  ('"RAJASTHAN"', '"JODHPUR EAST"', 2012, 0),
#  ('"RAJASTHAN"', '"JODHPUR WEST"', 2012, 0),
#  ('"TRIPURA"', '"KHOWAI"', 2012, 0),
#  ('"JAMMU & KASHMIR"', '"RAILWAYS KATRA"', 2012, 0),
#  ('"WEST BENGAL"', '"SILIGURI_PC"', 2012, 0),
#  ('"TRIPURA"', '"SIPAHIJALA"', 2012, 0),
#  ('"CHHATTISGARH"', '"SUKMA"', 2012, 0),
#  ('"TRIPURA"', '"UNAKOTI"', 2012, 0),
#  ('"MAHARASHTRA"', '"AHMEDNAGAR"', 2001, 1),
#  ('"BIHAR"', '"ARARIA"', 2001, 1),
#  ('"MADHYA PRADESH"', '"BALAGHAT"', 2001, 1),
#  ('"RAJASTHAN"', '"BARAN"', 2001, 1),
#  ('"MADHYA PRADESH"', '"BHOPAL"', 2001, 1),
#  ('"JHARKHAND"', '"CHATRA"', 2001, 1),
#  ('"RAJASTHAN"', '"DHOLPUR"', 2001, 1),
#  ('"ODISHA"', '"GAJAPATI"', 2001, 1),
#  ('"MADHYA PRADESH"', '"GWALIOR"', 2001, 1),
#  ('"MADHYA PRADESH"', '"HOSHANGABAD"', 2001, 1),
#  ('"CHHATTISGARH"', '"JAGDALPUR"', 2001, 1),
#  ('"RAJASTHAN"', '"JHALAWAR"', 2001, 1),
#  ('"RAJASTHAN"', '"JHUNJHUNU"', 2001, 1),
#  ('"KERALA"', '"KANNUR"', 2001, 1),
#  ('"ANDHRA PRADESH"', '"KHAMMAM"', 2001, 1),
#  ('"KARNATAKA"', '"KODAGU"', 2001, 1),
#  ('"ARUNACHAL PRADESH"', '"LOHIT"', 2001, 1),
#  ('"ANDHRA PRADESH"', '"MAHABOOBNAGAR"', 2001, 1),
#  ('"MADHYA PRADESH"', '"MANDLA"', 2001, 1),
#  ('"UTTAR PRADESH"', '"MORADABAD"', 2001, 1),
#  ('"MAHARASHTRA"', '"NAGPUR RLY."', 2001, 1),
#  ('"ANDHRA PRADESH"', '"NALGONDA"', 2001, 1),
#  ('"MAHARASHTRA"', '"NASIK RURAL"', 2001, 1),
#  ('"ANDHRA PRADESH"', '"NELLORE"', 2001, 1),
#  ('"KERALA"', '"PALAKKAD"', 2001, 1),
#  ('"GUJARAT"', '"PALANPUR"', 2001, 1),
#  ('"RAJASTHAN"', '"PALI"', 2001, 1),
#  ('"MADHYA PRADESH"', '"PANNA"', 2001, 1),
#  ('"ARUNACHAL PRADESH"', '"PAPUM PARE"', 2001, 1),
#  ('"MAHARASHTRA"', '"PUNE RURAL"', 2001, 1),
#  ('"MADHYA PRADESH"', '"RAJGARH"', 2001, 1),
#  ('"MADHYA PRADESH"', '"RATLAM"', 2001, 1),
#  ('"MADHYA PRADESH"', '"SAGAR"', 2001, 1),
#  ('"JHARKHAND"', '"SAHEBGANJ"', 2001, 1),
#  ('"CHHATTISGARH"', '"SARGUJA"', 2001, 1),
#  ('"MADHYA PRADESH"', '"SHEOPUR"', 2001, 1),
#  ('"MADHYA PRADESH"', '"SIHORE"', 2001, 1),
#  ('"RAJASTHAN"', '"SIROHI"', 2001, 1),
#  ('"ODISHA"', '"SUNDARGARH"', 2001, 1),
#  ('"GUJARAT"', '"SURAT RURAL"', 2001, 1),
#  ('"KERALA"', '"THRISSUR"', 2001, 1),
#  ('"RAJASTHAN"', '"UDAIPUR"', 2001, 1),
#  ('"UTTARAKHAND"', '"UDHAMSINGH NAGAR"', 2001, 1),
#  ('"GUJARAT"', '"VADODARA COMMR."', 2001, 1),
#  ('"KERALA"', '"WAYANADU"', 2001, 1),
#  ('"JHARKHAND"', '"GUMLA"', 2002, 1),
#  ('"RAJASTHAN"', '"JAIPUR EAST"', 2006, 1),
#  ('"RAJASTHAN"', '"JAIPUR RURAL"', 2006, 1),
#  ('"RAJASTHAN"', '"JAIPUR SOUTH"', 2006, 1),
#  ('"RAJASTHAN"', '"JODHPUR RURAL"', 2006, 1),
#  ('"RAJASTHAN"', '"KOTA CITY"', 2006, 1),
#  ('"RAJASTHAN"', '"KOTA RURAL"', 2006, 1),
#  ('"CHHATTISGARH"', '"GARIYABAND"', 2011, 1),
#  ('"CHHATTISGARH"', '"KONDAGAON"', 2012, 1),
#  ('"CHHATTISGARH"', '"MUNGELI"', 2012, 1),
#  ('"UTTAR PRADESH"', '"ALIGARH"', 2001, 2),
#  ('"MADHYA PRADESH"', '"BARWANI"', 2001, 2),
#  ('"ODISHA"', '"BOLANGIR"', 2001, 2),
#  ('"MADHYA PRADESH"', '"CHHINDWARA"', 2001, 2),
#  ('"RAJASTHAN"', '"DAUSA"', 2001, 2),
#  ('"MAHARASHTRA"', '"DHULE"', 2001, 2),
#  ('"MADHYA PRADESH"', '"GUNA"', 2001, 2),
#  ('"MADHYA PRADESH"', '"JABALPUR"', 2001, 2),
#  ('"RAJASTHAN"', '"JAIPUR"', 2001, 2),
#  ('"MADHYA PRADESH"', '"KHANDWA"', 2001, 2),
#  ('"NAGALAND"', '"MON"', 2001, 2),
#  ('"GUJARAT"', '"PANCHMAHAL"', 2001, 2),
#  ('"MADHYA PRADESH"', '"SHIVPURI"', 2001, 2),
#  ('"ARUNACHAL PRADESH"', '"SIANG EAST"', 2001, 2),
#  ('"SIKKIM"', '"SOUTH"', 2001, 2),
#  ('"MADHYA PRADESH"', '"TIKAMGARH"', 2001, 2),
#  ('"GUJARAT"', '"VADODARA RURAL"', 2001, 2),
#  ('"ASSAM"', '"UDALGURI"', 2005, 2),
#  ('"CHHATTISGARH"', '"BILASPUR"', 2001, 3),
#  ('"MADHYA PRADESH"', '"DHAR"', 2001, 3),
#  ('"CHHATTISGARH"', '"JANJGIR"', 2001, 3),
#  ('"RAJASTHAN"', '"KOTA"', 2001, 3),
#  ('"NAGALAND"', '"ZUNHEBOTO"', 2001, 3),
#  ('"SIKKIM"', '"EAST"', 2001, 4),
#  ('"CHHATTISGARH"', '"KORBA"', 2001, 4),
#  ('"ANDHRA PRADESH"', '"TOTAL"', 2001, 4),
#  ('"ASSAM"', '"N.C.HILLS"', 2002, 5),
#  ('"CHHATTISGARH"', '"SURAJPUR"', 2005, 5),
#  ('"CHHATTISGARH"', '"KANKER"', 2001, 6),
#  ('"NAGALAND"', '"PHEK"', 2001, 6),
#  ('"NAGALAND"', '"WOKHA"', 2001, 11),
#  ('"JHARKHAND"', '"KHUNTI"', 2007, 16),
#  ('"JHARKHAND"', '"RANCHI"', 2001, 18),
#  ('"NAGALAND"', '"KOHIMA"', 2001, 24),
#  ('"STATE/UT"', '"DISTRICT"', '"Year"', '"Murder"')]

# %% [markdown]
# # 3.8.1)	Insert records of STATE/UT, DISTRICT, YEAR, MURDER, ATTEMPT TO MURDER, and RAPE columns only from 01_District_wise_crimes_committed_IPC_2001_2012.csv into a new table

# %%
cursor.execute("CREATE TABLE district_wise_IPC_crimes (state_UT TEXT,District TEXT,Year INT,Murder INT, Attempt murder INT, Rape INT)")

# %%
with open(r"C:\Nimish\Flip Robo\01_District_wise_crimes_committed_IPC_2001_2012.csv") as file:
    no_records=0
    for row in file:
        cursor.execute('INSERT INTO district_wise_IPC_crimes VALUES(?,?,?,?,?,?)',row.split(','))
        db.commit()
        no_records +=1

print(no_records,"record(s) printed")
# Out:
# 9018 record(s) printed

# %% [markdown]
# # 3.8.2)	Write SQL query to find which District in each state/ut has the highest number of murders yearwise. Your output should show STATE/UT, YEAR, DISTRICT, and MURDERS.

# %%
result = cursor.execute("SELECT state_UT, Year, DISTRICT, MAX(MURDER) AS Highest_Murder FROM district_wise_IPC_crimes WHERE NOT DISTRICT = 'TOTAL' GROUP BY state_ut, Year")
rows=result.fetchall()
rows
# Out:
# [('A & N ISLANDS', 2001, 'ANDAMAN', 13),
#  ('A & N ISLANDS', 2002, 'ANDAMAN', 14),
#  ('A & N ISLANDS', 2003, 'ANDAMAN', 16),
#  ('A & N ISLANDS', 2004, 'ANDAMAN', 13),
#  ('A & N ISLANDS', 2005, 'ANDAMAN', 14),
#  ('A & N ISLANDS', 2006, 'ANDAMAN', 3),
#  ('A & N ISLANDS', 2007, 'A and N ISLANDS', 15),
#  ('A & N ISLANDS', 2008, 'ANDAMAN', 8),
#  ('A & N ISLANDS', 2009, 'ANDAMAN', 15),
#  ('A & N ISLANDS', 2010, 'ANDAMAN', 8),
#  ('A & N ISLANDS', 2011, 'ANDAMAN', 14),
#  ('A & N ISLANDS', 2012, 'SOUTH', 8),
#  ('ANDHRA PRADESH', 2001, 'RANGA REDDY', 214),
#  ('ANDHRA PRADESH', 2002, 'RANGA REDDY', 214),
#  ('ANDHRA PRADESH', 2003, 'GUNTUR', 210),
#  ('ANDHRA PRADESH', 2004, 'MAHABOOBNAGAR', 183),
#  ('ANDHRA PRADESH', 2005, 'MAHABOOBNAGAR', 212),
#  ('ANDHRA PRADESH', 2006, 'CYBERABAD', 193),
#  ('ANDHRA PRADESH', 2007, 'CYBERABAD', 186),
#  ('ANDHRA PRADESH', 2008, 'CYBERABAD', 197),
#  ('ANDHRA PRADESH', 2009, 'CYBERABAD', 186),
#  ('ANDHRA PRADESH', 2010, 'CYBERABAD', 187),
#  ('ANDHRA PRADESH', 2011, 'CYBERABAD', 213),
#  ('ANDHRA PRADESH', 2012, 'CYBERABAD', 198),
#  ('ARUNACHAL PRADESH', 2001, 'LOHIT', 16),
#  ('ARUNACHAL PRADESH', 2002, 'LOHIT', 14),
#  ('ARUNACHAL PRADESH', 2003, 'LOHIT', 16),
#  ('ARUNACHAL PRADESH', 2004, 'LOHIT', 10),
#  ('ARUNACHAL PRADESH', 2005, 'LOHIT', 14),
#  ('ARUNACHAL PRADESH', 2006, 'PAPUM PARE', 10),
#  ('ARUNACHAL PRADESH', 2007, 'LOHIT', 17),
#  ('ARUNACHAL PRADESH', 2008, 'LOHIT', 11),
#  ('ARUNACHAL PRADESH', 2009, 'SIANG WEST', 11),
#  ('ARUNACHAL PRADESH', 2010, 'SIANG WEST', 9),
#  ('ARUNACHAL PRADESH', 2011, 'LOHIT', 12),
#  ('ARUNACHAL PRADESH', 2012, 'LOHIT', 11),
#  ('ASSAM', 2001, 'DIBRUGARH', 110),
#  ('ASSAM', 2002, 'TINSUKIA', 115),
#  ('ASSAM', 2003, 'DIBRUGARH', 107),
#  ('ASSAM', 2004, 'DIBRUGARH', 125),
#  ('ASSAM', 2005, 'DIBRUGARH', 113),
#  ('ASSAM', 2006, 'DIBRUGARH', 104),
#  ('ASSAM', 2007, 'TINSUKIA', 143),
#  ('ASSAM', 2008, 'TINSUKIA', 114),
#  ('ASSAM', 2009, 'SONITPUR', 109),
#  ('ASSAM', 2010, 'TINSUKIA', 96),
#  ('ASSAM', 2011, 'TINSUKIA', 98),
#  ('ASSAM', 2012, 'KOKRAJHAR', 110),
#  ('BIHAR', 2001, 'PATNA', 434),
#  ('BIHAR', 2002, 'PATNA', 472),
#  ('BIHAR', 2003, 'PATNA', 484),
#  ('BIHAR', 2004, 'PATNA', 542),
#  ('BIHAR', 2005, 'PATNA', 436),
#  ('BIHAR', 2006, 'PATNA', 338),
#  ('BIHAR', 2007, 'PATNA', 317),
#  ('BIHAR', 2008, 'PATNA', 341),
#  ('BIHAR', 2009, 'PATNA', 314),
#  ('BIHAR', 2010, 'PATNA', 304),
#  ('BIHAR', 2011, 'PATNA', 248),
#  ('BIHAR', 2012, 'PATNA', 356),
#  ('CHANDIGARH', 2001, 'CHANDIGARH', 15),
#  ('CHANDIGARH', 2002, 'CHANDIGARH', 31),
#  ('CHANDIGARH', 2003, 'CHANDIGARH', 21),
#  ('CHANDIGARH', 2004, 'CHANDIGARH', 22),
#  ('CHANDIGARH', 2005, 'CHANDIGARH', 18),
#  ('CHANDIGARH', 2006, 'CHANDIGARH', 12),
#  ('CHANDIGARH', 2007, 'CHANDIGARH', 19),
#  ('CHANDIGARH', 2008, 'CHANDIGARH', 17),
#  ('CHANDIGARH', 2009, 'CHANDIGARH', 22),
#  ('CHANDIGARH', 2010, 'CHANDIGARH', 21),
#  ('CHANDIGARH', 2011, 'CHANDIGARH', 24),
#  ('CHANDIGARH', 2012, 'CHANDIGARH', 21),
#  ('CHHATTISGARH', 2001, 'SARGUJA', 105),
#  ('CHHATTISGARH', 2002, 'SARGUJA', 101),
#  ('CHHATTISGARH', 2003, 'BILASPUR', 95),
#  ('CHHATTISGARH', 2004, 'SARGUJA', 111),
#  ('CHHATTISGARH', 2005, 'BILASPUR', 94),
#  ('CHHATTISGARH', 2006, 'BIZAPUR', 139),
#  ('CHHATTISGARH', 2007, 'BIZAPUR', 113),
#  ('CHHATTISGARH', 2008, 'BILASPUR', 112),
#  ('CHHATTISGARH', 2009, 'RAIPUR', 101),
#  ('CHHATTISGARH', 2010, 'BILASPUR', 106),
#  ('CHHATTISGARH', 2011, 'BILASPUR', 112),
#  ('CHHATTISGARH', 2012, 'BILASPUR', 74),
#  ('D & N HAVELI', 2001, 'D and N HAVELI', 3),
#  ('D & N HAVELI', 2002, 'D and N HAVELI', 11),
#  ('D & N HAVELI', 2003, 'D and N HAVELI', 11),
#  ('D & N HAVELI', 2004, 'D and N HAVELI', 11),
#  ('D & N HAVELI', 2005, 'D and N HAVELI', 7),
#  ('D & N HAVELI', 2006, 'D and N HAVELI', 9),
#  ('D & N HAVELI', 2007, 'D and N HAVELI', 10),
#  ('D & N HAVELI', 2008, 'D and N HAVELI', 9),
#  ('D & N HAVELI', 2009, 'D and N HAVELI', 10),
#  ('D & N HAVELI', 2010, 'D and N HAVELI', 6),
#  ('D & N HAVELI', 2011, 'D and N HAVELI', 14),
#  ('D & N HAVELI', 2012, 'D and N HAVELI', 7),
#  ('DAMAN & DIU', 2001, 'DAMAN', 6),
#  ('DAMAN & DIU', 2002, 'DAMAN', 7),
#  ('DAMAN & DIU', 2003, 'DAMAN', 6),
#  ('DAMAN & DIU', 2004, 'DAMAN', 2),
#  ('DAMAN & DIU', 2005, 'DAMAN', 4),
#  ('DAMAN & DIU', 2006, 'DAMAN', 6),
#  ('DAMAN & DIU', 2007, 'DAMAN', 12),
#  ('DAMAN & DIU', 2008, 'DAMAN', 2),
#  ('DAMAN & DIU', 2009, 'DAMAN', 5),
#  ('DAMAN & DIU', 2010, 'DAMAN', 5),
#  ('DAMAN & DIU', 2011, 'DAMAN', 6),
#  ('DAMAN & DIU', 2012, 'DAMAN', 3),
#  ('DELHI UT', 2001, 'DELHI UT TOTAL', 547),
#  ('DELHI UT', 2002, 'DELHI UT TOTAL', 531),
#  ('DELHI UT', 2003, 'DELHI UT TOTAL', 485),
#  ('DELHI UT', 2004, 'DELHI UT TOTAL', 481),
#  ('DELHI UT', 2005, 'DELHI UT TOTAL', 455),
#  ('DELHI UT', 2006, 'DELHI UT TOTAL', 476),
#  ('DELHI UT', 2007, 'DELHI UT TOTAL', 495),
#  ('DELHI UT', 2008, 'DELHI UT TOTAL', 554),
#  ('DELHI UT', 2009, 'DELHI UT TOTAL', 552),
#  ('DELHI UT', 2010, 'DELHI UT TOTAL', 565),
#  ('DELHI UT', 2011, 'DELHI UT TOTAL', 543),
#  ('DELHI UT', 2012, 'DELHI UT TOTAL', 521),
#  ('GOA', 2001, 'NORTH GOA', 22),
#  ('GOA', 2002, 'NORTH GOA', 18),
#  ('GOA', 2003, 'NORTH GOA', 22),
#  ('GOA', 2004, 'NORTH GOA', 23),
#  ('GOA', 2005, 'SOUTH GOA', 23),
#  ('GOA', 2006, 'NORTH GOA', 24),
#  ('GOA', 2007, 'SOUTH GOA', 18),
#  ('GOA', 2008, 'NORTH GOA', 26),
#  ('GOA', 2009, 'NORTH GOA', 33),
#  ('GOA', 2010, 'NORTH GOA', 25),
#  ('GOA', 2011, 'NORTH GOA', 33),
#  ('GOA', 2012, 'NORTH GOA', 28),
#  ('GUJARAT', 2001, 'SURAT COMMR.', 98),
#  ('GUJARAT', 2002, 'AHMEDABAD COMMR.', 222),
#  ('GUJARAT', 2003, 'AHMEDABAD COMMR.', 90),
#  ('GUJARAT', 2004, 'AHMEDABAD COMMR.', 92),
#  ('GUJARAT', 2005, 'SURAT COMMR.', 86),
#  ('GUJARAT', 2006, 'SURAT COMMR.', 103),
#  ('GUJARAT', 2007, 'SURAT COMMR.', 108),
#  ('GUJARAT', 2008, 'SURAT COMMR.', 97),
#  ('GUJARAT', 2009, 'SURAT COMMR.', 101),
#  ('GUJARAT', 2010, 'SURAT COMMR.', 87),
#  ('GUJARAT', 2011, 'SURAT COMMR.', 100),
#  ('GUJARAT', 2012, 'SURAT COMMR.', 98),
#  ('HARYANA', 2001, 'SONIPAT', 73),
#  ('HARYANA', 2002, 'SONIPAT', 82),
#  ('HARYANA', 2003, 'GURGAON', 62),
#  ('HARYANA', 2004, 'FARIDABAD', 67),
#  ('HARYANA', 2005, 'FARIDABAD', 76),
#  ('HARYANA', 2006, 'GURGAON', 93),
#  ('HARYANA', 2007, 'GURGAON', 93),
#  ('HARYANA', 2008, 'SONIPAT', 84),
#  ('HARYANA', 2009, 'GURGAON', 84),
#  ('HARYANA', 2010, 'HISSAR', 91),
#  ('HARYANA', 2011, 'GURGAON', 89),
#  ('HARYANA', 2012, 'SONIPAT', 86),
#  ('HIMACHAL PRADESH', 2001, 'KANGRA', 24),
#  ('HIMACHAL PRADESH', 2002, 'KANGRA', 28),
#  ('HIMACHAL PRADESH', 2003, 'KANGRA', 38),
#  ('HIMACHAL PRADESH', 2004, 'MANDI', 19),
#  ('HIMACHAL PRADESH', 2005, 'KANGRA', 21),
#  ('HIMACHAL PRADESH', 2006, 'KANGRA', 19),
#  ('HIMACHAL PRADESH', 2007, 'KANGRA', 22),
#  ('HIMACHAL PRADESH', 2008, 'KANGRA', 19),
#  ('HIMACHAL PRADESH', 2009, 'KANGRA', 29),
#  ('HIMACHAL PRADESH', 2010, 'KANGRA', 27),
#  ('HIMACHAL PRADESH', 2011, 'KANGRA', 21),
#  ('HIMACHAL PRADESH', 2012, 'KANGRA', 24),
#  ('JAMMU & KASHMIR', 2001, 'BARAMULLA', 144),
#  ('JAMMU & KASHMIR', 2002, 'BARAMULLA', 121),
#  ('JAMMU & KASHMIR', 2003, 'POONCH', 111),
#  ('JAMMU & KASHMIR', 2004, 'BARAMULLA', 86),
#  ('JAMMU & KASHMIR', 2005, 'BARAMULLA', 78),
#  ('JAMMU & KASHMIR', 2006, 'DODA', 65),
#  ('JAMMU & KASHMIR', 2007, 'BARAMULLA', 47),
#  ('JAMMU & KASHMIR', 2008, 'JAMMU', 31),
#  ('JAMMU & KASHMIR', 2009, 'SRINAGAR', 23),
#  ('JAMMU & KASHMIR', 2010, 'SOPORE', 30),
#  ('JAMMU & KASHMIR', 2011, 'JAMMU', 18),
#  ('JAMMU & KASHMIR', 2012, 'JAMMU', 13),
#  ('JHARKHAND', 2001, 'RANCHI', 243),
#  ('JHARKHAND', 2002, 'RANCHI', 270),
#  ('JHARKHAND', 2003, 'RANCHI', 250),
#  ('JHARKHAND', 2004, 'RANCHI', 270),
#  ('JHARKHAND', 2005, 'RANCHI', 239),
#  ('JHARKHAND', 2006, 'RANCHI', 253),
#  ('JHARKHAND', 2007, 'RANCHI', 203),
#  ('JHARKHAND', 2008, 'RANCHI', 209),
#  ('JHARKHAND', 2009, 'RANCHI', 202),
#  ('JHARKHAND', 2010, 'RANCHI', 183),
#  ('JHARKHAND', 2011, 'GUMLA', 201),
#  ('JHARKHAND', 2012, 'GUMLA', 192),
#  ('KARNATAKA', 2001, 'BANGALORE COMMR.', 221),
#  ('KARNATAKA', 2002, 'BANGALORE COMMR.', 201),
#  ('KARNATAKA', 2003, 'BANGALORE COMMR.', 216),
#  ('KARNATAKA', 2004, 'BANGALORE COMMR.', 214),
#  ('KARNATAKA', 2005, 'BANGALORE COMMR.', 242),
#  ('KARNATAKA', 2006, 'BANGALORE COMMR.', 218),
#  ('KARNATAKA', 2007, 'BANGALORE COMMR.', 246),
#  ('KARNATAKA', 2008, 'BANGALORE COMMR.', 253),
#  ('KARNATAKA', 2009, 'BANGALORE COMMR.', 256),
#  ('KARNATAKA', 2010, 'BANGALORE COMMR.', 266),
#  ('KARNATAKA', 2011, 'BANGALORE COMMR.', 232),
#  ('KARNATAKA', 2012, 'BANGALORE COMMR.', 266),
#  ('KERALA', 2001, 'TRIVANDRUM', 53),
#  ('KERALA', 2002, 'TRIVANDRUM', 58),
#  ('KERALA', 2003, 'PALAKKAD', 52),
#  ('KERALA', 2004, 'KOLLAM', 46),
#  ('KERALA', 2005, 'THRISSUR', 41),
#  ('KERALA', 2006, 'PALAKKAD', 44),
#  ('KERALA', 2007, 'KOLLAM', 43),
#  ('KERALA', 2008, 'THRISSUR', 38),
#  ('KERALA', 2009, 'PALAKKAD', 36),
#  ('KERALA', 2010, 'PALAKKAD', 42),
#  ('KERALA', 2011, 'PALAKKAD', 41),
#  ('KERALA', 2012, 'TRIVANDRUM RURAL', 42),
#  ('LAKSHADWEEP', 2001, 'LAKSHADWEEP', 1),
#  ('LAKSHADWEEP', 2002, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2003, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2004, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2005, 'LAKSHADWEEP', 1),
#  ('LAKSHADWEEP', 2006, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2007, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2008, 'LAKSHADWEEP', 1),
#  ('LAKSHADWEEP', 2009, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2010, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2011, 'LAKSHADWEEP', 0),
#  ('LAKSHADWEEP', 2012, 'LAKSHADWEEP', 0),
#  ('MADHYA PRADESH', 2001, 'JHABUA', 124),
#  ('MADHYA PRADESH', 2002, 'JHABUA', 133),
#  ('MADHYA PRADESH', 2003, 'JHABUA', 119),
#  ('MADHYA PRADESH', 2004, 'JHABUA', 139),
#  ('MADHYA PRADESH', 2005, 'JHABUA', 129),
#  ('MADHYA PRADESH', 2006, 'JHABUA', 117),
#  ('MADHYA PRADESH', 2007, 'INDORE', 111),
#  ('MADHYA PRADESH', 2008, 'INDORE', 125),
#  ('MADHYA PRADESH', 2009, 'INDORE', 132),
#  ('MADHYA PRADESH', 2010, 'INDORE', 108),
#  ('MADHYA PRADESH', 2011, 'INDORE', 135),
#  ('MADHYA PRADESH', 2012, 'INDORE', 123),
#  ('MAHARASHTRA', 2001, 'MUMBAI', 295),
#  ('MAHARASHTRA', 2002, 'MUMBAI', 252),
#  ('MAHARASHTRA', 2003, 'MUMBAI', 242),
#  ('MAHARASHTRA', 2004, 'MUMBAI', 253),
#  ('MAHARASHTRA', 2005, 'MUMBAI', 212),
#  ('MAHARASHTRA', 2006, 'MUMBAI COMMR.', 239),
#  ('MAHARASHTRA', 2007, 'MUMBAI COMMR.', 230),
#  ('MAHARASHTRA', 2008, 'MUMBAI COMMR.', 210),
#  ('MAHARASHTRA', 2009, 'MUMBAI COMMR.', 217),
#  ('MAHARASHTRA', 2010, 'MUMBAI COMMR.', 228),
#  ('MAHARASHTRA', 2011, 'MUMBAI COMMR.', 203),
#  ('MAHARASHTRA', 2012, 'MUMBAI COMMR.', 215),
#  ('MANIPUR', 2001, 'IMPHAL(WEST)', 44),
#  ('MANIPUR', 2002, 'IMPHAL(WEST)', 32),
#  ('MANIPUR', 2003, 'IMPHAL(WEST)', 28),
#  ('MANIPUR', 2004, 'THOUBAL', 38),
#  ('MANIPUR', 2005, 'CHURACHANDPUR', 49),
#  ('MANIPUR', 2006, 'CHURACHANDPUR', 43),
#  ('MANIPUR', 2007, 'IMPHAL WEST', 61),
#  ('MANIPUR', 2008, 'THOUBAL', 46),
#  ('MANIPUR', 2009, 'IMPHAL WEST', 32),
#  ('MANIPUR', 2010, 'IMPHAL EAST', 19),
#  ('MANIPUR', 2011, 'IMPHAL WEST', 24),
#  ('MANIPUR', 2012, 'THOUBAL', 16),
#  ('MEGHALAYA', 2001, 'KHASI HILLS EAST', 50),
#  ('MEGHALAYA', 2002, 'KHASI HILLS EAST', 48),
#  ('MEGHALAYA', 2003, 'JAINTIA HILLS', 52),
#  ('MEGHALAYA', 2004, 'KHASI HILLS EAST', 33),
#  ('MEGHALAYA', 2005, 'JAINTIA HILLS', 43),
#  ('MEGHALAYA', 2006, 'JAINTIA HILLS', 51),
#  ('MEGHALAYA', 2007, 'JAINTIA HILLS', 43),
#  ('MEGHALAYA', 2008, 'JAINTIA HILLS', 38),
#  ('MEGHALAYA', 2009, 'JAINTIA HILLS', 40),
#  ('MEGHALAYA', 2010, 'JAINTIA HILLS', 48),
#  ('MEGHALAYA', 2011, 'JAINTIA HILLS', 52),
#  ('MEGHALAYA', 2012, 'JAINTIA HILLS', 44),
#  ('MIZORAM', 2001, 'AIZAWL', 12),
#  ('MIZORAM', 2002, 'CHAMPHAI', 6),
#  ('MIZORAM', 2003, 'AIZAWL', 14),
#  ('MIZORAM', 2004, 'AIZAWL', 10),
#  ('MIZORAM', 2005, 'AIZAWL', 4),
#  ('MIZORAM', 2006, 'AIZAWL', 7),
#  ('MIZORAM', 2007, 'AIZAWL', 18),
#  ('MIZORAM', 2008, 'AIZAWL', 12),
#  ('MIZORAM', 2009, 'AIZAWL', 14),
#  ('MIZORAM', 2010, 'AIZAWL', 23),
#  ('MIZORAM', 2011, 'AIZAWL', 10),
#  ('MIZORAM', 2012, 'AIZAWL', 12),
#  ('NAGALAND', 2001, 'DIMAPUR', 36),
#  ('NAGALAND', 2002, 'DIMAPUR', 32),
#  ('NAGALAND', 2003, 'KOHIMA', 28),
#  ('NAGALAND', 2004, 'DIMAPUR', 22),
#  ('NAGALAND', 2005, 'DIMAPUR', 23),
#  ('NAGALAND', 2006, 'KOHIMA', 31),
#  ('NAGALAND', 2007, 'DIMAPUR', 30),
#  ('NAGALAND', 2008, 'DIMAPUR', 64),
#  ('NAGALAND', 2009, 'DIMAPUR', 15),
#  ('NAGALAND', 2010, 'DIMAPUR', 20),
#  ('NAGALAND', 2011, 'DIMAPUR', 15),
#  ('NAGALAND', 2012, 'DIMAPUR', 26),
#  ('ODISHA', 2001, 'MAYURBHANJ', 74),
#  ('ODISHA', 2002, 'SUNDARGARH', 87),
#  ('ODISHA', 2003, 'SUNDARGARH', 83),
#  ('ODISHA', 2004, 'MAYURBHANJ', 77),
#  ('ODISHA', 2005, 'SUNDARGARH', 82),
#  ('ODISHA', 2006, 'KEONJHAR', 84),
#  ('ODISHA', 2007, 'MAYURBHANJ', 98),
#  ('ODISHA', 2008, 'KEONJHAR', 91),
#  ('ODISHA', 2009, 'KEONJHAR', 109),
#  ('ODISHA', 2010, 'MAYURBHANJ', 88),
#  ('ODISHA', 2011, 'MAYURBHANJ', 103),
#  ('ODISHA', 2012, 'KEONJHAR', 97),
#  ('PUDUCHERRY', 2001, 'PONDICHERRY', 25),
#  ('PUDUCHERRY', 2002, 'PONDICHERRY', 29),
#  ('PUDUCHERRY', 2003, 'PONDICHERRY', 29),
#  ('PUDUCHERRY', 2004, 'PONDICHERRY', 25),
#  ('PUDUCHERRY', 2005, 'PONDICHERRY', 19),
#  ('PUDUCHERRY', 2006, 'PONDICHERRY', 28),
#  ('PUDUCHERRY', 2007, 'PONDICHERRY', 30),
#  ('PUDUCHERRY', 2008, 'PUDUCHERRY', 30),
#  ('PUDUCHERRY', 2009, 'PUDUCHERRY', 31),
#  ('PUDUCHERRY', 2010, 'PUDUCHERRY', 29),
#  ('PUDUCHERRY', 2011, 'PUDUCHERRY', 32),
#  ('PUDUCHERRY', 2012, 'PUDUCHERRY', 24),
#  ('PUNJAB', 2001, 'JALANDHAR', 74),
#  ('PUNJAB', 2002, 'LUDHIANA', 68),
#  ('PUNJAB', 2003, 'LUDHIANA', 64),
#  ('PUNJAB', 2004, 'JALANDHAR', 74),
#  ('PUNJAB', 2005, 'JALANDHAR', 63),
#  ('PUNJAB', 2006, 'JALANDHAR', 80),
#  ('PUNJAB', 2007, 'JALANDHAR', 63),
#  ('PUNJAB', 2008, 'LUDHIANA', 73),
#  ('PUNJAB', 2009, 'LUDHIANA', 68),
#  ('PUNJAB', 2010, 'CP LUDHIANA', 90),
#  ('PUNJAB', 2011, 'CP LUDHIANA', 76),
#  ('PUNJAB', 2012, 'CP LUDHIANA', 79),
#  ('RAJASTHAN', 2001, 'JAIPUR', 91),
#  ('RAJASTHAN', 2002, 'BHARATPUR', 87),
#  ('RAJASTHAN', 2003, 'JAIPUR', 92),
#  ('RAJASTHAN', 2004, 'BHARATPUR', 92),
#  ('RAJASTHAN', 2005, 'BHARATPUR', 91),
#  ('RAJASTHAN', 2006, 'ALWAR', 75),
#  ('RAJASTHAN', 2007, 'ALWAR', 89),
#  ('RAJASTHAN', 2008, 'ALWAR', 101),
#  ('RAJASTHAN', 2009, 'ALWAR', 103),
#  ('RAJASTHAN', 2010, 'BHARATPUR', 83),
#  ('RAJASTHAN', 2011, 'ALWAR', 104),
#  ('RAJASTHAN', 2012, 'ALWAR', 100),
#  ('SIKKIM', 2001, 'EAST', 13),
#  ('SIKKIM', 2002, 'EAST', 6),
#  ('SIKKIM', 2003, 'EAST', 7),
#  ('SIKKIM', 2004, 'WEST', 5),
#  ('SIKKIM', 2005, 'EAST', 5),
#  ('SIKKIM', 2006, 'EAST', 10),
#  ('SIKKIM', 2007, 'WEST', 6),
#  ('SIKKIM', 2008, 'EAST', 5),
#  ('SIKKIM', 2009, 'EAST', 7),
#  ('SIKKIM', 2010, 'SOUTH', 7),
#  ('SIKKIM', 2011, 'EAST', 8),
#  ('SIKKIM', 2012, 'EAST', 3),
#  ('STATE/UT', 'YEAR', 'DISTRICT', 'MURDER'),
#  ('TAMIL NADU', 2001, 'CHENNAI', 91),
#  ('TAMIL NADU', 2002, 'DHARMAPURI', 94),
#  ('TAMIL NADU', 2003, 'DHARMAPURI', 90),
#  ('TAMIL NADU', 2004, 'CHENGAI', 79),
#  ('TAMIL NADU', 2005, 'CHENNAI', 123),
#  ('TAMIL NADU', 2006, 'CHENNAI', 131),
#  ('TAMIL NADU', 2007, 'CHENNAI', 145),
#  ('TAMIL NADU', 2008, 'CHENNAI', 100),
#  ('TAMIL NADU', 2009, 'CHENNAI', 96),
#  ('TAMIL NADU', 2010, 'CHENNAI', 103),
#  ('TAMIL NADU', 2011, 'CHENNAI', 168),
#  ('TAMIL NADU', 2012, 'CHENNAI', 180),
#  ('TRIPURA', 2001, 'WEST', 125),
#  ('TRIPURA', 2002, 'WEST', 113),
#  ('TRIPURA', 2003, 'WEST', 136),
#  ('TRIPURA', 2004, 'WEST', 97),
#  ('TRIPURA', 2005, 'WEST', 61),
#  ('TRIPURA', 2006, 'WEST', 74),
#  ('TRIPURA', 2007, 'WEST', 65),
#  ('TRIPURA', 2008, 'WEST', 72),
#  ('TRIPURA', 2009, 'WEST', 61),
#  ('TRIPURA', 2010, 'WEST', 83),
#  ('TRIPURA', 2011, 'WEST', 71),
#  ('TRIPURA', 2012, 'WEST', 26),
#  ('UTTAR PRADESH', 2001, 'MUZAFFARNAGAR', 324),
#  ('UTTAR PRADESH', 2002, 'MUZAFFARNAGAR', 287),
#  ('UTTAR PRADESH', 2003, 'BAREILLY', 194),
#  ('UTTAR PRADESH', 2004, 'MUZAFFARNAGAR', 253),
#  ('UTTAR PRADESH', 2005, 'BAREILLY', 224),
#  ('UTTAR PRADESH', 2006, 'MUZAFFARNAGAR', 230),
#  ('UTTAR PRADESH', 2007, 'MUZAFFARNAGAR', 213),
#  ('UTTAR PRADESH', 2008, 'KANPUR NAGAR', 168),
#  ('UTTAR PRADESH', 2009, 'GHAZIABAD', 254),
#  ('UTTAR PRADESH', 2010, 'GHAZIABAD', 216),
#  ('UTTAR PRADESH', 2011, 'MEERUT', 189),
#  ('UTTAR PRADESH', 2012, 'MEERUT', 202),
#  ('UTTARAKHAND', 2001, 'HARIDWAR', 94),
#  ('UTTARAKHAND', 2002, 'HARIDWAR', 75),
#  ('UTTARAKHAND', 2003, 'HARIDWAR', 75),
#  ('UTTARAKHAND', 2004, 'HARIDWAR', 56),
#  ('UTTARAKHAND', 2005, 'HARIDWAR', 65),
#  ('UTTARAKHAND', 2006, 'UDHAMSINGH NAGAR', 74),
#  ('UTTARAKHAND', 2007, 'HARIDWAR', 55),
#  ('UTTARAKHAND', 2008, 'HARIDWAR', 74),
#  ('UTTARAKHAND', 2009, 'HARIDWAR', 67),
#  ('UTTARAKHAND', 2010, 'UDHAMSINGH NAGAR', 55),
#  ('UTTARAKHAND', 2011, 'HARIDWAR', 56),
#  ('UTTARAKHAND', 2012, 'HARIDWAR', 74),
#  ('WEST BENGAL', 2001, '24 PARGANAS NORTH', 202),
#  ('WEST BENGAL', 2002, '24 PARGANAS NORTH', 204),
#  ('WEST BENGAL', 2003, '24 PARGANAS NORTH', 193),
#  ('WEST BENGAL', 2004, '24 PARGANAS NORTH', 177),
#  ('WEST BENGAL', 2005, '24 PARGANAS NORTH', 168),
#  ('WEST BENGAL', 2006, '24 PARGANAS NORTH', 154),
#  ('WEST BENGAL', 2007, '24 PARGANAS NORTH', 194),
#  ('WEST BENGAL', 2008, '24 PARGANAS SOUTH', 239),
#  ('WEST BENGAL', 2009, '24 PARGANAS NORTH', 229),
#  ('WEST BENGAL', 2010, 'PASCHIM MIDNAPUR', 268),
#  ('WEST BENGAL', 2011, '24 PARGANAS SOUTH', 247),
#  ('WEST BENGAL', 2012, '24 PARGANAS SOUTH', 224)]

# %% [markdown]
# This is the list for each state's district having the most murders yearwise.

# %% [markdown]
# # 3.8.3)	Store the above data (the result of 3.8.2) in DataFrame and analyze districts that appear 3 or more than 3 years and print the corresponding state/ut, district, murders, and year in descending order.

# %%
df = pd.DataFrame(rows, columns=['state_UT', 'Year', 'DISTRICT', 'MURDER'])
df
# Out:
#           state_UT  Year           DISTRICT MURDER
# 0    A & N ISLANDS  2001            ANDAMAN     13
# 1    A & N ISLANDS  2002            ANDAMAN     14
# 2    A & N ISLANDS  2003            ANDAMAN     16
# 3    A & N ISLANDS  2004            ANDAMAN     13
# 4    A & N ISLANDS  2005            ANDAMAN     14
# ..             ...   ...                ...    ...
# 416    WEST BENGAL  2008  24 PARGANAS SOUTH    239
# 417    WEST BENGAL  2009  24 PARGANAS NORTH    229
# 418    WEST BENGAL  2010   PASCHIM MIDNAPUR    268
# 419    WEST BENGAL  2011  24 PARGANAS SOUTH    247
# 420    WEST BENGAL  2012  24 PARGANAS SOUTH    224
#
# [421 rows x 4 columns]

# %% [markdown]
# We have stored the data in the dataframe 'df'

# %%
df['Year'] = pd.to_numeric(df['Year'],errors='coerce')
df['MURDER'] = pd.to_numeric(df['MURDER'],errors='coerce')

# %%
district_counts = df['DISTRICT'].value_counts()
selected_districts = district_counts[district_counts >= 3].index
selected_districts
# Out:
# Index(['WEST', 'D and N HAVELI', 'CHANDIGARH', 'LAKSHADWEEP',
#        'BANGALORE COMMR.', 'PATNA', 'DAMAN', 'DELHI UT TOTAL', 'AIZAWL',
#        'KANGRA', 'NORTH GOA', 'RANCHI', 'HARIDWAR', 'DIMAPUR', 'ANDAMAN',
#        'SURAT COMMR.', 'CHENNAI', 'EAST', 'JAINTIA HILLS', 'LOHIT',
#        '24 PARGANAS NORTH', 'MUMBAI COMMR.', 'PONDICHERRY', 'CYBERABAD',
#        'INDORE', 'JHABUA', 'ALWAR', 'BILASPUR', 'BARAMULLA', 'MUMBAI',
#        'MAYURBHANJ', 'PALAKKAD', 'PUDUCHERRY', 'JALANDHAR', 'GURGAON',
#        'MUZAFFARNAGAR', 'TINSUKIA', 'DIBRUGARH', 'KEONJHAR', 'LUDHIANA',
#        'BHARATPUR', 'SONIPAT', 'CP LUDHIANA', 'IMPHAL(WEST)', 'SARGUJA',
#        'IMPHAL WEST', 'THOUBAL', 'SUNDARGARH', 'AHMEDABAD COMMR.',
#        '24 PARGANAS SOUTH', 'KHASI HILLS EAST', 'JAMMU'],
#       dtype='object')

# %% [markdown]
# These are all the districts which are appearing 3 or more than 3 years

# %%
district_counts = df.groupby(['state_UT', 'DISTRICT']).size().reset_index(name='Count')
sorted_df = district_counts.sort_values(by='Count', ascending=False)
sorted_df
# Out:
#              state_UT          DISTRICT  Count
# 21        DAMAN & DIU             DAMAN     12
# 20       D & N HAVELI    D and N HAVELI     12
# 47        LAKSHADWEEP       LAKSHADWEEP     12
# 81            TRIPURA              WEST     12
# 15         CHANDIGARH        CHANDIGARH     12
# ..                ...               ...    ...
# 11              ASSAM         KOKRAJHAR      1
# 8   ARUNACHAL PRADESH        PAPUM PARE      1
# 4      ANDHRA PRADESH            GUNTUR      1
# 2       A & N ISLANDS             SOUTH      1
# 91        WEST BENGAL  PASCHIM MIDNAPUR      1
#
# [92 rows x 3 columns]

# %% [markdown]
# We have sorted the dataframe of districts appearing 3 or more than 3 times in descening order

# %% [markdown]
# # 3.8.4)	Use appropriate graphs to show your data (the result of 3.8.3)

# %%
plt.figure(figsize=(15,4))
sns.barplot(data=sorted_df,x='DISTRICT',y='Count',errwidth=0,palette='coolwarm')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From above we see that Daman and some other districts were the places that had the most murdere cases respective to their states

# %%
plt.figure(figsize=(15,5))
sns.barplot(x=df['DISTRICT'], y=df['MURDER'],errwidth=0,palette='viridis')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# From above we see that most murders occured in Delhi's total and Patna

# %%
plt.figure(figsize=(18,8))
sns.scatterplot(x='Year',y='MURDER',data=df,hue='state_UT',palette='tab10',style='state_UT')
plt.legend(loc='upper right', bbox_to_anchor=(0.7, -0.1),
          fancybox=True, shadow=True, ncol=5)

# %% [markdown]
# From above we see that in every year Delhi UT tops the cahrt with most murders except the year 2004 where Bihar secures the first place.
